# %% [markdown]
# # 6. 웹크롤러 만들기 - 기초

# %% [markdown]
# ![banner](../image/4-1.jpg)

# %% [markdown]
# ## 웹이란 무엇일까요?

# %% [markdown]
# > 웹은 ‘월드 와이드 웹(World Wide Web)’의 줄임말이에요. 첫 글자를 따서 WWW라고 부르기도 합니다. ‘웹(web)’을 영어 뜻 그대로 풀이하면 ‘거미줄’이라는 뜻인데, 거미줄처럼 서로 연결된 모습을 상상하면 딱 알맞는 용어겠죠?
#
# > 웹은 뼈대를 이루는 html, 꾸며주기를 담당하는 css, 동작을 담당하는 javascript로 이루어져 있어요. 이를 실제로 살펴볼까요? Chrome 브라우져에서 오른쪽 버튼을 눌러 검사 옵션에 들어가보세요.

# %% [markdown]
# ![banner](../image/4-4.jpg)

# %% [markdown]
# > 오른쪽에서 첫번째 Elements 창이 보이시나요? 보고계신 내용이 웹페이지의 뼈대를 이루는 html문서에요. 보는것 처럼 html은 태그(tag)를 활용해서 만들어졌으며 이를 어려운말로 마크업언어(Markup language)라고 합니다. 두번째 창에 보면 웹페이지를 꾸며주는 css를 확인할수 있고 Source 탭을 누르면 웹페이지의 작동을 관리하는 javascript를 확인해볼수 있어요.

# %% [markdown]
# ![banner](../image/4-3.jpg)

# %% [markdown]
# ## 웹의 구조

# %% [markdown]
# > 아래 그림은 모델-뷰-컨트롤러(Model–View–Controller, MVC) 패턴을 보여줘요. MCV패턴은 소프트웨어 공학에서 사용되는 소프트웨어 디자인 패턴을 말해요

# %% [markdown]
# ![banner](../image/4-5.jpg)

# %% [markdown]
# ## 웹페이지의 동작 과정

# %% [markdown]
# > 먼저 사용자(`Client`)가 서버(`Server`)로 정보제공을 요청합니다. 이를 요청(`Request`)라고 해요. Request의 방식은 `GET`방식과 `POST`방식이 있어요. 우리가 주소창에 `url`을 적은 후 `Enter`를 치는것이 가장 대표정인 `GET`방식의 요청입니다.
#
# > `GET`방식은 `url` 뒤에 붙여서 서버로 보내는 방식이에요. `?` 뒤에 값이 이어붙는 방식이죠. 이 때문에 보내는 값을 볼수 있을뿐만 아니라 많은 데이터를 보내기엔 적합하지 않습니다. 그래서 일반적으로 데이터를 주고받기보다는 서버에 요청만 할 때 주로 사용해요.
#
# > `POST`방식은 `GET`방식과 달리 숨겨진 형태로 서버에 전송할때 보내는 방식이에요. 때문에 상대적으로 `GET`방식에 비해선 많은 데이터를 보낼수 있고, 값이 보이지 않기 때문에 주로 로그인을 할때 서버로 정보를 보내기 위해 사용하는 방식이에요.

# %% [markdown]
# > 서버가 요청을 받으면 사용자에게 보내기 위해 데이터베이스(`Model`)로 부터 값을 받고 `html`과 `css`, 그리고 `javscript`를 이용해서 컴포넌트(`Component`)를 만들어서 사용자에게 보내줘요. 물론 데이터만 보내는것도 가능해요. 이럴땐 주로 사전형(`dict`)으로 생긴 `json`형태로 값을 보내준답니다.
#
# > 이런 과정을 통해 여러분은 웹사이트를 모니터에서 보게 되는거에요!

# %% [markdown]
# ![banner](../image/4-6.jpg)

# %% [markdown]
# ## 웹크롤러란 무엇일까요?

# %% [markdown]
# > 웹 크롤러(web crawler)는 조직적, 자동화된 방법으로 월드 와이드 웹을 탐색하는 컴퓨터 프로그램입니다. 검색엔진의 경우는 자료의 최신화를 위해서 사용하기도 하고 주로 정보수집을 위해 활용하고 있어요.
#
# > 정식 명칭은 'Web Scraping'이라고 하며 영문 자료를 찾으실때는 해당 명칭을 활용하는게 좋아요.

# %% [markdown]
# ## 네이버 부동산 크롤링 하기

# %% [markdown]
# 아래 네이버 부동산 페이지를 크롤링하여 강원도 춘천시의 매물을 확인해 봅시다.

# %% [markdown]
# ![4-9](../image/4-8.png)

# %% [markdown]
# ### 한페이지 크롤링

# %%
import requests
from bs4 import BeautifulSoup
from pandas import DataFrame

# %%
# 페이지(page) 부분을 수정하여 다름 페이지로 넘어갈 수 있어요
# 위치(location) 코드를 수정하면 다른 지역도 크롤링 할수 있어요
url = 'https://land.naver.com/article/divisionInfo.nhn?rletTypeCd=A01&tradeTypeCd=&hscpTypeCd=A01%3AA03%3AA04&\
cortarNo=4211000000&articleOrderCode=&cpId=&minPrc=&maxPrc=&minWrrnt=&maxWrrnt=&minLease=&maxLease=&minSpc=\
&maxSpc=&subDist=&mviDate=&hsehCnt=&rltrId=&mnex=&siteOrderCode=&cmplYn=&page={}\
&location=2459#_content_list_target'.format(1)

# %% [markdown]
# 문자열 자료형의 format함수를 이용하면 편해요!

# %%
# get방식으로 서버에 요청해 봅시다
response = requests.get(url)
response.text
# Out:
# '<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">\n<html lang="ko">\n<head>\n<title>\n\n\t춘천시, 강원도, 매물 : 네이버 부동산\t\n\n\n\n</title>\n\t<!--[if lte IE 8]>\n\t\t<meta http-equiv="X-UA-Compatible" content="IE=edge" />\n\t<![endif]-->\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\n<meta name="referrer" contents="always" />\n\n\n<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">\n\n\n\n<!-- og:tag -->\n<link rel="canonical" href="http://land.naver.com">\n<meta property="og:site_name" content="land" />\n<meta property="og:title" content="네이버 부동산" />\n<meta property="og:type" content="article" />\n<meta property="og:description" content="[강원도 춘천시] 아파트 매물" />\n<meta name="description" content="[강원도 춘천시] 아파트 매물">\n\n\t<meta property="og:image" content="https://ssl.pstatic.net/static.land/static/service/20181108-2/lnb/ico_land_large_og_tag.png"/>\n\n<meta property="og:article:author" content="네이버 부동산" />\n\n<meta property="og:url" content="https://land.naver.com/article/divisionInfo.nhn?rletTypeCd=A01&tradeTypeCd=&hscpTypeCd=A01%3AA03%3AA04&cortarNo=4211000000&articleOrderCode=&cpId=&minPrc=&maxPrc=&minWrrnt=&maxWrrnt=&minLease=&maxLease=&minSpc=&maxSpc=&subDist=&mviDate=&hsehCnt=&rltrId=&mnex=&siteOrderCode=&cmplYn=&page=1&location=2459" />\n<meta property="og:article:author:url" content="http://land.naver.com/" />\n\n<!-- //og:tag -->\n\n\n\t\n\t\t<link rel="stylesheet" href="https://ssl.pstatic.net/static.land/static/service/css/201901241734/min/article/land_article.css" type="text/css">\n\t\t<link rel="stylesheet" href="https://ssl.pstatic.net/static.land/static/service/css/201901241734/min/article/land_article.map.css" type="text/css">\t\n\t\n\t\n\n<script type="text/javascript">\tdocument.domain = \'naver.com\';</script>\n\n</head>\n<body class="" >\n\t<form id="paramForm" method="get" action="">\n\t\t<input type="hidden" id="rletTypeCd" name="rletTypeCd" value="A01"/>\n\t\t<input type="hidden" id="tradeTypeCd" name="tradeTypeCd" value=""/>\n\t\t<input type="hidden" id="hscpTypeCd" name="hscpTypeCd" value="A01:A03:A04"/>\n\t\t<input type="hidden" id="cortarNo" name="cortarNo" value="4211000000"/>\n\t\t<input type="hidden" id="articleOrderCode" name="articleOrderCode" value=""/>\n\t\t<input type="hidden" id="cpId" name="cpId" value=""/>\n\n\t\t<input type="hidden" id="minPrc" name="minPrc" value=""/>\n\t\t<input type="hidden" id="maxPrc" name="maxPrc" value=""/>\n\t\t<input type="hidden" id="minWrrnt" name="minWrrnt" value=""/>\n\t\t<input type="hidden" id="maxWrrnt" name="maxWrrnt" value=""/>\n\t\t<input type="hidden" id="minLease" name="minLease" value=""/>\n\t\t<input type="hidden" id="maxLease" name="maxLease" value=""/>\n\t\t<input type="hidden" id="minSpc" name="minSpc" value=""/>\n\t\t<input type="hidden" id="maxSpc" name="maxSpc" value=""/>\n\t\t<input type="hidden" id="subDist" name="subDist" value=""/>\n\t\t<input type="hidden" id="mviDate" name="mviDate" value=""/>\n\t\t<input type="hidden" id="hsehCnt" name="hsehCnt" value=""/>\n\t\t<input type="hidden" id="rltrId" name="rltrId" value=""/>\n\t\t<input type="hidden" id="mnex" name="mnex" value=""/>\n\t\t<input type="hidden" id="siteOrderCode" name="siteOrderCode" value=""/>\n\t\t<input type="hidden" id="cmplYn" name="cmplYn" value=""/>\n\t</form>\n\t<div id="wrap">\n\t\t\n\t<div id="u_skip">\n\t  <a href="#lnb" onclick="document.getElementById(\'lnb\').tabIndex = -1;document.getElementById(\'lnb\').focus();return false;"><span>메인 메뉴로 바로가기</span></a>\n\t  <a href="#container" onclick="document.getElementById(\'container\').tabIndex = -1;document.getElementById(\'container\').focus();return false;"><span>하위 메뉴로 바로가기</span></a>\n\t  <a href="#content" onclick="document.getElementById(\'content\').tabIndex = -1;document.getElementById(\'content\').focus();return false;"><span>본문으로 바로가기</span></a>\n\t</div>\t\n\t\t\n\n\n\n\n<!-- header -->\n<script s ...

# %% [markdown]
# response.text는 단순 문자열 형태입니다. BeautifulSoup를 활용하면 이것을 html의 형태로 바꿀수 있어요

# %%
# BeautifulSoup를 이용해서 보기좋게 파싱(parsing)할 수 있어요
soup = BeautifulSoup(response.text, 'html.parser')
soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html lang="ko">
# <head>
# <title>
#
# 	춘천시, 강원도, 매물 : 네이버 부동산
#
#
#
# </title>
# <!--[if lte IE 8]>
# 		<meta http-equiv="X-UA-Compatible" content="IE=edge" />
# 	<![endif]-->
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta contents="always" name="referrer">
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <!-- og:tag -->
# <link href="http://land.naver.com" rel="canonical"/>
# <meta content="land" property="og:site_name"/>
# <meta content="네이버 부동산" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="[강원도 춘천시] 아파트 매물" property="og:description"/>
# <meta content="[강원도 춘천시] 아파트 매물" name="description"/>
# <meta content="https://ssl.pstatic.net/static.land/static/service/20181108-2/lnb/ico_land_large_og_tag.png" property="og:image">
# <meta content="네이버 부동산" property="og:article:author"/>
# <meta content="https://land.naver.com/article/divisionInfo.nhn?rletTypeCd=A01&amp;tradeTypeCd=&amp;hscpTypeCd=A01%3AA03%3AA04&amp;cortarNo=4211000000&amp;articleOrderCode=&amp;cpId=&amp;minPrc=&amp;maxPrc=&amp;minWrrnt=&amp;maxWrrnt=&amp;minLease=&amp;maxLease=&amp;minSpc=&amp;maxSpc=&amp;subDist=&amp;mviDate=&amp;hsehCnt=&amp;rltrId=&amp;mnex=&amp;siteOrderCode=&amp;cmplYn=&amp;page=1&amp;location=2459" property="og:url"/>
# <meta content="http://land.naver.com/" property="og:article:author:url"/>
# <!-- //og:tag -->
# <link href="https://ssl.pstatic.net/static.land/static/service/css/201901241734/min/article/land_article.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.land/static/service/css/201901241734/min/article/land_article.map.css" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">	document.domain = 'naver.com';</script>
# </meta></meta></head>
# <body class="">
# <form action="" id="paramForm" method="get">
# <input id="rletTypeCd" name="rletTypeCd" type="hidden" value="A01"/>
# <input id="tradeTypeCd" name="tradeTypeCd" type="hidden" value=""/>
# <input id="hscpTypeCd" name="hscpTypeCd" type="hidden" value="A01:A03:A04"/>
# <input id="cortarNo" name="cortarNo" type="hidden" value="4211000000"/>
# <input id="articleOrderCode" name="articleOrderCode" type="hidden" value=""/>
# <input id="cpId" name="cpId" type="hidden" value=""/>
# <input id="minPrc" name="minPrc" type="hidden" value=""/>
# <input id="maxPrc" name="maxPrc" type="hidden" value=""/>
# <input id="minWrrnt" name="minWrrnt" type="hidden" value=""/>
# <input id="maxWrrnt" name="maxWrrnt" type="hidden" value=""/>
# <input id="minLease" name="minLease" type="hidden" value=""/>
# <input id="maxLease" name="maxLease" type="hidden" value=""/>
# <input id="minSpc" name="minSpc" type="hidden" value=""/>
# <input id="maxSpc" name="maxSpc" type="hidden" value=""/>
# <input id="subDist" name="subDist" type="hidden" value=""/>
# <input id="mviDate" name="mviDate" type="hidden" value=""/>
# <input id="hsehCnt" name="hsehCnt" type="hidden" value=""/>
# <input id="rltrId" name="rltrId" type="hidden" value=""/>
# <input id="mnex" name="mnex" type="hidden" value=""/>
# <input id="siteOrderCode" name="siteOrderCode" type="hidden" value=""/>
# <input id="cmplYn" name="cmplYn" type="hidden" value=""/>
# </form>
# <div id="wrap">
# <div id="u_skip">
# <a href="#lnb" onclick="document.getElementById('lnb').tabIndex = -1;document.getElementById('lnb').focus();return false;"><span>메인 메뉴로 바로가기</span></a>
# <a href="#container" onclick="document.getElementById('container').tabIndex = -1;document.getElementById('container').focus();return false;"><span>하위 메뉴로 바로가기</span></a>
# <a href="#content" onclick="document.getElementById('content').tabIndex = -1;document.getElementById('content').focus();return false;"><span>본문으로 바로가기</span></a>
# </div>
# <!-- header -->
# <script src="https://ssl.pstatic.net/static.land/static/service/js/201901241734/lib/lcslog.js" type="text/javascript"></script>
# <script src="https://wcs.naver.net/wcslog.js" type="text/javascript"></script>
# <script type="text/javascript">
# 	lcs_do();
#
# 	if(!wcs_add) var wcs_add = {};
# 	wcs_add["wa"] = "60717a12f2b3c8";
# 	wcs_do();
# </script>
# <div class="header_one" id="header">
# <div class="gnb_wrap">
# <div class="inner_wrap">
# <div class="item_area NE=a:STA">
# <h1 class="logo_area">
# <a class="logo_naver NPI=a:naverlogo" href="http://www.naver.com/"><i class="icon">NAVER</i></a>
# <a class="logo_land NPI=a:land" href="http://land.naver.com/"><i class="icon">부동산</i></a>
# </h1>
# <div class="inner_gnb_search">
# <h2 class="blind">검색영역</h2>
# <fieldset>
# <legend>검색</legend>
# <!-- [D] 입력위해 focus 가지면 sta_text_ovr 추가 -->
# <input name="where" type="hidden" value="nexearch"/>
# <input name="sm" type="hidden" value="top_hty"/>
# <input name="fbm" type="hidden" value="1"/>
# <input id="serviceInternalSearchQuery" name="query" type="hidden" value=""/>
# <input id="internalSearchURL" name="internalSearchURL" type="hidden" value="https://land.naver.com"/>
# <input accesskey="s" class="search_input sta_search_text" id="queryInputHeader" onfocus="searchInputBoxFocus(this);" onkeyup="serviceInternalSearchEnterCheck(event,0);" query="" searchareaclicked="false" searchtype="Promotion" title="검색" type="text" value=""/>
# <a class="search_button type_inside NPI=a:search" href="#" onclick="serviceInternalSearch();return false;"><i class="icon">검색</i></a>
# <a class="search_button type_integration NPI=a:nx" href="#" onclick="serviceInternalTotalSearch();return false;" title="새창 열림"><i class="icon">통합검색</i></a>
# </fieldset>
# </div>
# </div>
# <div class="gnb_area">
# <div id="gnb">
# <script charset="utf-8" src="https://ssl.pstatic.net/static.gn/templates/gnb_utf8.nhn?20190131" type="text/javascript"></script>
# </div>
# </div>
# </div>
# </div>
# <div class="nav_wrap" id="lnb">
# <h2 class="blind">메인메뉴</h2>
# <div class="inner_wrap">
# <!-- [D] 활성화 클래스 on -->
# <ul class="nav_list NE=a:LNB">
# <li class="menu main_home">
# <a class="NPI=a:home" href="/">부동산홈</a>
# </li>
# <li class="menu main_article_beta">
# <a class="NPI=a:article_beta" href="https://new.land.naver.com/complexes">매물베타</a>
# </li>
# <li class="menu main_article on hidden">
# <a class="NPI=a:article" href="/article/">매물</a>
# </li>
# <li class="menu main_isale">
# <a class="NPI=a:sale" href="/isale/">분양</a>
# </li>
# <li class="menu main_news">
# <a class="NPI=a:news" href="/news/">뉴스</a>
# </li>
# <li class="menu main_community">
# <a class="NPI=a:community" href="/community/">커뮤니티</a>
# </li>
# <li class="menu main_auction">
# <a class="NPI=a:auction" href="/auction/">경매</a>
# </li>
# <li class="menu main_theme">
# <a class="NPI=a:theme" href="https://new.land.naver.com/themes">테마부동산</a>
# </li>
# <li class="menu main_mypage">
# <a class="NPI=a:mypage" href="/mypage/interestArticle.nhn">MY페이지</a>
# </li>
# <!--[if lte IE 9]>
# 						<li id="_ieVerCheck" class="hidden ie9"></li>
# 					<![endif]-->
# </ul>
# <div class="button_area NE=a:LNB">
# <a class="type_admin NPI=a:landad" href="http://landad.naver.com/" target="_blank">부동산관리센터</a>
# </div>
# </div>
# </div>
# </div>
# <!-- //header -->
# <div class="search NE=a:pf1" id="spot">
# <!-- 100830 부동산가이드 배너 -->
# <div id="guidebanner_area">
# </div>
# <!-- 지도 상단 카테고리 -->
# <div class="map_top">
# <ul class="cate">
# <div id="top_rlet_tp">
# <li class="m1 NPI=a:apt"><a btnid="m1" class="selected" href="javascript:void(0);" tpcd="A01">아파트</a></li>
# <li class="m2 NPI=a:oft"><a btnid="m2" class="" href="javascript:void(0);" tpcd="A02">오피스텔</a></li>
# <li class="m3 NPI=a:bun"><a btnid="m3" class="" href="javascript:void(0);" tpcd="B01">분양권</a></li>
# <li class="m4 NPI=a:hos"><a btnid="m4" class="" href="javascript:void(0);" tpcd="C03">주택</a></li>
# <li class="m5 NPI=a:lnd"><a btnid="m5" class="" href="javascript:void(0);" tpcd="E03">토지</a></li>
# <li class="m6 NPI=a:onr"><a btnid="m6" class="" href="javascript:void(0);" tpcd="C01">원룸</a></li>
# <li class="m7 NPI=a:shp"><a btnid="m7" class="" href="javascript:void(0);" tpcd="D02">상가</a></li>
# <li class="m8 NPI=a:ofc"><a btnid="m8" class="" href="javascript:void(0);" tpcd="D01">사무실</a></li>
# <li class="m9 NPI=a:fct"><a btnid="m9" class="" href="javascript:void(0);" tpcd="E02">공장</a></li>
# <li class="m10 NPI=a:rdv"><a btnid="m10" class="" href="javascript:void(0);" tpcd="F01">재개발</a></li>
# <li class="m11 NPI=a:etc"><a btnid="m11" class="" href="javascript:void(0);" tpcd="D03">건물</a></li>
# </div>
# <div id="top_trad_tp">
# <li class="m12 NPI=a:all"><a btnid="m12" class="selected" href="javascript:void(0);" tpcd="all">전체</a></li>
# <li class="m13 NPI=a:sale"><a btnid="m13" class="" href="javascript:void(0);" tpcd="A1">매매</a></li>
# <li class="m14 NPI=a:rent"><a btnid="m14" class="" href="javascript:void(0);" tpcd="B1">전세</a></li>
# <li class="m15 NPI=a:monthly"><a btnid="m15" class="" href="javascript:void(0);" tpcd="B2">월세</a></li>
# <li class="m16"><a btnid="m16" class="" href="javascript:void(0);" tpcd="B3">단기임대</a></li>
# </div>
# </ul>
# </div>
# <!-- //지도 상단 카테고리 -->
# </div>
# <div class="map_main NE=a:pf2" id="map">
# <!-- 위치 선택 -->
# <div class="location" id="locationArea">
# <div class="loc_view">
# <div class="sel selectbox-noscript" id="loc_view1">
# <select class="selectbox-source forload" title="시/도">
# <option value="1100000000">서울시</option>
# <option value="4100000000">경기도</option>
# <option value="2800000000">인천시</option>
# <option value="2600000000">부산시</option>
# <option value="3000000000">대전시</option>
# <option value="2700000000">대구시</option>
# <option value="3100000000">울산시</option>
# <option value="3600000000">세종시</option>
# <option value="2900000000">광주시</option>
# <option selected="" value="4200000000">강원도</option>
# <option value="4300000000">충청북도</option>
# <option value="4400000000">충청남도</option>
# <option value="4700000000">경상북도</option>
# <option value="4800000000">경상남도</option>
# <option value="4500000000">전라북도</option>
# <option value="4600000000">전라남도</option>
# <option value="5000000000">제주도</option>
# </select>
# <div class="selectbox-box">
# <div class="selectbox-label">강원도</div>
# </div>
# <div class="selectBoxDivList selectbox-layer">
# <div class="selectbox-list"></div>
# </div>
# </div>
# <span class="bar">&gt;</span>
# <div class="sel selectbox-noscript" id="loc_view2">
# <select class="selectbox-source forload" title="시/군/구">
# <option value="4215000000">강릉시</option>
# <option value="4282000000">고성군</option>
# <option value="4217000000">동해시</option>
# <option value="4223000000">삼척시</option>
# <option value="4221000000">속초시</option>
# <option value="4280000000">양구군</option>
# <option value="4283000000">양양군</option>
# <option value="4275000000">영월군</option>
# <option value="4213000000">원주시</option>
# <option value="4281000000">인제군</option>
# <option value="4277000000">정선군</option>
# <option value="4278000000">철원군</option>
# <option selected="" value="4211000000">춘천시</option>
# <option value="4219000000">태백시</option>
# <option value="4276000000">평창군</option>
# <option value="4272000000">홍천군</option>
# <option value="4279000000">화천군</option>
# <option value="4273000000">횡성군</option>
# </select>
# <div class="selectbox-box">
# <div class="selectbox-label">춘천시</div>
# </div>
# <div class="selectBoxDivList selectbox-layer">
# <div class="selectbox-list"></div>
# </div>
# </div>
# <span class="bar">&gt;</span>
# <div class="sel selectbox-noscript" id="loc_view3">
# <select class="selectbox-source forload" title="읍/면/동">
# <option class="selectbox-default" value="_">읍⁄면⁄동</option>
# <option value="4211012200">교동</option>
# <option value="4211011700">근화동</option>
# <option value="4211010300">낙원동</option>
# <option value="4211034000">남면</option>
# <option value="4211040000">남산면</option>
# <option value="4211039000">동내면</option>
# <option value="4211031000">동면</option>
# <option value="4211032000">동산면</option>
# <option value="4211010100">봉의동</option>
# <option value="4211038000">북산면</option>
# <option value="4211011900">사농동</option>
# <option value="4211036000">사북면</option>
# <option value="4211012500">삼천동</option>
# <option value="4211035000">서면</option>
# <option value="4211012400">석사동</option>
# <option value="4211011300">소양로1가</option>
# <option value="4211011400">소양로2가</option>
# <option value="4211011500">소양로3가</option>
# <option value="4211011600">소양로4가</option>
# <option value="4211012700">송암동</option>
# <option value="4211012800">신동</option>
# <option value="4211033000">신동면</option>
# <option value="4211025000">신북읍</option>
# <option value="4211011100">약사동</option>
# <option value="4211010700">옥천동</option>
# <option value="4211012100">온의동</option>
# <option value="4211010200">요선동</option>
# <option value="4211011800">우두동</option>
# <option value="4211011000">운교동</option>
# <option value="4211010800">조양동</option>
# <option value="4211010900">죽림동</option>
# <option value="4211012900">중도동</option>
# <option value="4211010400">중앙로1가</option>
# <option value="4211010500">중앙로2가</option>
# <option value="4211010600">중앙로3가</option>
# <option value="4211012600">칠전동</option>
# <option value="4211012300">퇴계동</option>
# <option value="4211011200">효자동</option>
# <option value="4211012000">후평동</option>
# </select>
# <div class="selectbox-box">
# <div class="selectbox-label">읍⁄면⁄동</div>
# </div>
# <div class="selectBoxDivList selectbox-layer" style="width:85px;">
# <div class="selectbox-list"></div>
# </div>
# </div>
# </div>
# <div class="lastest">
# <p>최근 검색한 지역과 단지 <a href="javascript:void(0)" title="최근 검색한 지역과 단지">펼치기</a></p>
# <div class="list_wrap" id="recentComplexList" style="display:none;">
# <ol id="recentComplexList" style="padding:4px 0 0 11px;width:147px;height:17px;color:#666"><li>지역과 단지가 없습니다.</li></ol>
# </div>
# </div>
# </div>
# <!-- //위치 선택 -->
# <div class="map_viewer">
# <div class="map_area" id="mapAreaDivision" style="display: inline;">
# <div class="map_real" id="mapReal" tabindex="-1"></div>
# <div class="map_guide map_on" id="mapGuidePop" style="display:none;"></div>
# </div>
# <!-- 지도 범례 -->
# <div class="ly_legend NE=a:lgl" id="_ly_legend_container" style="display:none;">
# <div class="ly_mask"></div>
# <div class="ly_inner">
# <div class="tab_area" id="_legend_indextab">
# <a class="tab1 NPI=a:gtab" href="javascript:void(0);" info="https://help.naver.com/support/contents/contents.nhn?serviceNo=768&amp;categoryNo=1107" onclick="$$.getSingle('.btn_more', $('_ly_legend_container')).className='btn_more NPI=a:gmore';$$.getSingle('.btn_more', $('_ly_legend_container')).setAttribute('info', this.getAttribute('info'));$$.getSingle('UL._cadastral', $('_legend_tabs')).style.display='none';$$.getSingle('UL._normal', $('_legend_tabs')).style.display='block';$ElementList($$('SPAN.on', $('_legend_indextab'))).removeClass('on'); $Element($$.getSingle('.tab1 SPAN', $('_legend_indextab'))).addClass('on');$ElementList($$('.type_on', $('_legend_tabs'))).removeClass('type_on');$Element($$.getSingle('.type1', $('_legend_tabs'))).addClass('type_on');" tabindex="-1"><span>일반지도 범례</span></a>
# <a class="tab2 NPI=a:ctab" href="javascript:void(0);" info="https://help.naver.com/support/contents/contents.nhn?serviceNo=768&amp;categoryNo=2144" onclick="$$.getSingle('.btn_more', $('_ly_legend_container')).className='btn_more NPI=a:cmore';$$.getSingle('.btn_more', $('_ly_legend_container')).setAttribute('info', this.getAttribute('info'));$$.getSingle('UL._normal', $('_legend_tabs')).style.display='none';$$.getSingle('UL._cadastral', $('_legend_tabs')).style.display='block';$ElementList($$('SPAN.on', $('_legend_indextab'))).removeClass('on'); $Element($$.getSingle('.tab2 SPAN', $('_legend_indextab'))).addClass('on');$ElementList($$('.type_on', $('_legend_tabs'))).removeClass('type_on');$Element($$.getSingle('.type6', $('_legend_tabs'))).addClass('type_on');" tabindex="-1"><span class="on">지적편집도 범례</span></a>
# </div>
# <div class="ly_cont" id="_legend_tabs">
# <h3 class="blind" id="legend1">일반지도 범례</h3>
# <ul class="sub_tab _normal" style="display:none">
# <li class="type1">
# <a class="NPI=a:gboundary" href="javascript:void(0);" onclick="$ElementList($$('.type_on', $('_legend_tabs'))).removeClass('type_on'); $Element($$.getSingle('.type1', $('_legend_tabs'))).addClass('type_on');" tabindex="-1">경계</a>
# <div class="tab_cont">
# <ul>
# <li class="col1">국가경계</li>
# <li class="col2">광역시</li>
# <li class="col1">시도·시군구경계</li>
# <li class="col2">일반시</li>
# <li class="col3">택지지구경계</li>
# <li class="col3">문화거리</li>
# </ul>
# </div>
# </li>
# <li class="type2">
# <a class="NPI=a:groad" href="javascript:void(0);" onclick="$ElementList($$('.type_on', $('_legend_tabs'))).removeClass('type_on'); $Element($$.getSingle('.type2', $('_legend_tabs'))).addClass('type_on');" tabindex="-1">도로</a>
# <div class="tab_cont">
# <ul>
# <li class="col1">고속도로·고속화도로</li>
# <li class="col2">일반도로</li>
# <li class="col1">국도</li>
# <li class="col2">공사중도로</li>
# <li class="col1">지방도</li>
# <li class="col2">인터체인지</li>
# <li class="col1">주요도로</li>
# <li class="col2">교차로</li>
# </ul>
# </div>
# </li>
# <li class="type3">
# <a class="NPI=a:gtraffic" href="javascript:void(0);" onclick="$ElementList($$('.type_on', $('_legend_tabs'))).removeClass('type_on'); $Element($$.getSingle('.type3', $('_legend_tabs'))).addClass('type_on');" tabindex="-1">교통</a>
# <div class="tab_cont">
# <ul>
# <li class="col1">서울1 (인천)</li>
# <li class="col2">공항철도</li>
# <li class="col1">분당선</li>
# <li class="col2">광주1</li>
# <li class="col1">부산1</li>
# <li class="col2">대전1</li>
# <li class="col1">대구1</li>
# <li class="col2">중앙선</li>
# </ul>
# </div>
# </li>
# <li class="type4">
# <a class="NPI=a:gclimb" href="javascript:void(0);" onclick="$ElementList($$('.type_on', $('_legend_tabs'))).removeClass('type_on'); $Element($$.getSingle('.type4', $('_legend_tabs'))).addClass('type_on');" tabindex="-1">등산</a>
# <div class="tab_cont">
# <ul>
# <li class="col1">거리·소요시간</li>
# <li class="col2">매표소</li>
# <li class="col1">주요등산로</li>
# <li class="col2">등산안내소</li>
# <li class="col1">보조등산로</li>
# <li class="col2">대피소</li>
# <li class="col1">옛길등산로</li>
# <li class="col2">산장</li>
# </ul>
# </div>
# </li>
# <li class="type5">
# <a class="NPI=a:gapt" href="javascript:void(0);" onclick="$ElementList($$('.type_on', $('_legend_tabs'))).removeClass('type_on'); $Element($$.getSingle('.type5', $('_legend_tabs'))).addClass('type_on');" tabindex="-1">아파트</a>
# <div class="tab_cont">
# <ul>
# <li class="col1">아파트세대수</li>
# <li class="col1">아파트층·호수 (18층,1호~4호)</li>
# <li class="col1">아파트평형 (105.8m² = 32평)</li>
# </ul>
# </div>
# </li>
# </ul>
# <h3 class="blind" id="legend1">지적편집도 범례</h3>
# <ul class="sub_tab _cadastral">
# <li class="type6 type_on">
# <a class="NPI=a:cnum" href="javascript:void(0);" onclick="$ElementList($$('.type_on', $('_legend_tabs'))).removeClass('type_on'); $Element($$.getSingle('.type6', $('_legend_tabs'))).addClass('type_on');" tabindex="-1">지번·경계</a>
# <div class="tab_cont">
# <ul>
# <li class="col1">대표지번</li>
# <li class="col2">시군구경계</li>
# <li class="col1">독립지번</li>
# <li class="col2">법정동경계</li>
# <li class="col1">지번</li>
# <li class="col2">행정동경계</li>
# <li class="col1">지적경계</li>
# <li class="col2">읍면경계</li>
# </ul>
# </div>
# </li>
# <li class="type7">
# <a class="NPI=a:cdevelop" href="javascript:void(0);" onclick="$ElementList($$('.type_on', $('_legend_tabs'))).removeClass('type_on'); $Element($$.getSingle('.type7', $('_legend_tabs'))).addClass('type_on');" tabindex="-1">개발</a>
# <div class="tab_cont">
# <ul>
# <li class="col1">택지개발지구</li>
# <li class="col2">도시개발구역</li>
# <li class="col1">신도시</li>
# <li class="col2">경제자유구역</li>
# <li class="col1">정비구역</li>
# <li class="col2">재개발구역</li>
# <li class="col1">보금자리개발지구</li>
# <li class="col2">주택재개발</li>
# </ul>
# </div>
# </li>
# <li class="type8">
# <a class="NPI=a:cuse" href="javascript:void(0);" onclick="$ElementList($$('.type_on', $('_legend_tabs'))).removeClass('type_on'); $Element($$.getSingle('.type8', $('_legend_tabs'))).addClass('type_on');" tabindex="-1">용도</a>
# <div class="tab_cont">
# <ul>
# <li class="col1">전용주거지역</li>
# <li class="col2">공업지역</li>
# <li class="col1">일반주거지역</li>
# <li class="col2">녹지지역</li>
# <li class="col1">준주거지역</li>
# <li class="col2">관리지역</li>
# <li class="col1">상업지역</li>
# <li class="col2">농림지역</li>
# </ul>
# </div>
# </li>
# <li class="type9">
# <a class="NPI=a:crailroad" href="javascript:void(0);" onclick="$ElementList($$('.type_on', $('_legend_tabs'))).removeClass('type_on'); $Element($$.getSingle('.type9', $('_legend_tabs'))).addClass('type_on');" tabindex="-1">도로·철로</a>
# <div class="tab_cont">
# <ul>
# <li class="col1">장기계획도로</li>
# <li class="col2">예정철도</li>
# <li class="col1">예정고속도로</li>
# <li class="col2">공사중철도</li>
# <li class="col1">공사중고속도로1</li>
# <li class="col2">공사중지하철</li>
# <li class="col1">공사중고속도로2</li>
# <li class="col2">일반철도</li>
# </ul>
# </div>
# </li>
# </ul>
# <a class="btn_more NPI=a:cmore" href="javascript:void(0);" info="https://help.naver.com/support/contents/contents.nhn?serviceNo=768&amp;categoryNo=2144" onclick="window.open(this.getAttribute('info'));" tabindex="-1">더보기</a>
# </div>
# <div class="ly_btn">
# <a class="btn_clse NPI=a:close" href="javascript:void(0);" onclick="$('_ly_legend_container').style.display='none';" tabindex="-1">닫기</a>
# </div>
# </div>
# </div>
# <!-- //지도 범례 -->
# <!-- 매물정보 레이어, 중개업소정보 레이어 -->
# <div class="address_list NE=a:lcl" id="depthAddrNameListDivision" style="display: block;">
# <div class="backgroud_png"></div>
# <h3 class="area_tit">지역리스트 <span style="padding-top:15px;">(단지수)</span></h3>
# <div class="area scroll" id="divisionScrollList">
# <div>
# <ul>
# <li><a class="NPI=a:area,r:1,i:4211012200" href="#" onclick="nhn.article.common.moveArticle({'cortarNo':4211012200});return false;">교동</a><em>(0)</em></li>
# <li><a class="NPI=a:area,r:2,i:4211011700" href="#" onclick="nhn.article.common.moveArticle({'cortarNo':4211011700});return false;">근화동</a><em>(3)</em></li>
# <li><a class="NPI=a:area,r:3,i:4211010300" href="#" onclick="nhn.article.common.moveArticle({'cortarNo':4211010300});return false;">낙원동</a><em>(0)</em></li>
# <li><a class="NPI=a:area,r:4,i:4211034000" href="#" onclick="nhn.article.common.moveArticle({'cortarNo':4211034000});return false;">남면</a><em>(0)</em></li>
# <li><a class="NPI=a:area,r:5,i:4211040000" href="#" onclick="nhn.article.common.moveArticle({'cortarNo':4211040000});return false;">남산면</a><em>(1)</em></li>
# <li><a class="NPI=a:area,r:6,i:4211039000" href="#" onclick="nhn.article.common.moveArticle({'cortarNo':4211039000});return false;">동내면</a><em>(5)</em></li>
# <li><a class="NPI=a:area,r:7,i:4211031000" href="#" onclick="nhn.article.common.moveArticle({'cortarNo':4211031000});return false;">동면</a><em>(8)</em></li>
# <li><a class="NPI=a:area,r:8,i:4211032000" href="#" onclick="nhn.article.common.moveArticle({'cortarNo':4211032000});return false;">동산면</a><em>(0)</em></li>
# <li><a class="NPI=a:area,r:9,i:4211010100" href="#" onclick="nhn.article.common.moveArticle({'cortarNo':4211010100});return false;">봉의동</a><em>(0)</em></li>
# <li><a class="NPI=a:area,r:10,i:4211038000" href="#" onclick="nhn.article.common.moveArticle({'cortarNo':4211038000});return false;">북산면</a><em>(0)</em></li>
# <li><a class="NPI=a:area,r:11,i:4211011900" href="#" onclick="nhn.article.common.moveArticle({'cortarNo':4211011900});return false;">사농동</a><em>(4)</em></li>
# <li><a class="NPI=a:area,r:12,i:4211036000" href="#" onclick="nhn.article.common.moveArticle({'cortarNo':4211036000});return false;">사북면</a><em>(0)</em></li>
# <li><a class="NPI=a:area,r:13,i:4211012500" href="#" onclick="nhn.article.common.moveArticle({'cortarNo':4211012500});return false;">삼천동</a><em>(0)</em></li>
# <li><a class="NPI=a:area,r:14,i:4211035000" href="#" onclick="nhn.article.common.moveArticle({'cortarNo':4211035000});return false;">서면</a><em>(0)</em></li>
# <li><a class="NPI=a:area,r:15,i:4211012400" href="#" onclick="nhn.article.common.moveArticle({'cortarNo':4211012400});return false;">석사동</a><em>(19)</em></li>
# <li><a class="NPI=a:area,r:16,i:4211011300" href="#" onclick="nhn.article.common.moveArticle({'cortarNo':4211011300});return false;">소양로1가</a><em>(0)</em></li>
# <li><a class="NPI=a:area,r:17,i:4211011400" href="#" onclick="nhn.article.common.moveArticle({'cortarNo':4211011400});return false;">소양로2가</a><em>(3)</em></li>
# <li><a class="NPI=a:area,r:18,i:4211011500" href="#" onclick="nhn.article.common.moveArticle({'cortarNo':4211011500});return false;">소양로3가</a><em>(0)</em></li>
# <li><a class="NPI=a:area,r:19,i:4211011600" href="#" onclick="nhn.article.common.moveArticle({'cortarNo':4211011600});return false;">소양로4가</a><em>(0)</em></li>
# <li><a class="NPI=a:area,r:20,i:4211012700" href="#" onclick="nhn.article.common.moveArticle({'cortarNo':4211012700});return false;">송암동</a><em>(0)</em></li>
# <li><a class="NPI=a:area,r:21,i:4211012800" href="#" onclick="nhn.article.common.moveArticle({'cortarNo':4211012800});return false;">신동</a><em>(0)</em></li>
# <li><a class="NPI=a:area,r:22,i:4211033000" href="#" onclick="nhn.article.common.moveArticle({'cortarNo':4211033000});return false;">신동면</a><em>(0)</em></li>
# <li><a class="NPI=a:area,r:23,i:4211025000" href="#" onclick="nhn.article.common.moveArticle({'cortarNo':4211025000});return false;">신북읍</a><em>(2)</em></li>
# <li><a class="NPI=a:area,r:24,i:4211011100" href="#" onclick="nhn.article.common.moveArticle({'cortarNo':4211011100});return false;">약사동</a><em>(0)</em></li>
# <li><a class="NPI=a:area,r:25,i:4211010700" href="#" onclick="nhn.article.common.moveArticle({'cortarNo':4211010700});return false;">옥천동</a><em>(0)</em></li>
# <li><a class="NPI=a:area,r:26,i:4211012100" href="#" onclick="nhn.article.common.moveArticle({'cortarNo':4211012100});return false;">온의동</a><em>(8)</em></li>
# <li><a class="NPI=a:area,r:27,i:4211010200" href="#" onclick="nhn.article.common.moveArticle({'cortarNo':4211010200});return false;">요선동</a><em>(1)</em></li>
# <li><a class="NPI=a:area,r:28,i:4211011800" href="#" onclick="nhn.article.common.moveArticle({'cortarNo':4211011800});return false;">우두동</a><em>(4)</em></li>
# <li><a class="NPI=a:area,r:29,i:4211011000" href="#" onclick="nhn.article.common.moveArticle({'cortarNo':4211011000});return false;">운교동</a><em>(1)</em></li>
# <li><a class="NPI=a:area,r:30,i:4211010800" href="#" onclick="nhn.article.common.moveArticle({'cortarNo':4211010800});return false;">조양동</a><em>(1)</em></li>
# <li><a class="NPI=a:area,r:31,i:4211010900" href="#" onclick="nhn.article.common.moveArticle({'cortarNo':4211010900});return false;">죽림동</a><em>(2)</em></li>
# <li><a class="NPI=a:area,r:32,i:4211012900" href="#" onclick="nhn.article.common.moveArticle({'cortarNo':4211012900});return false;">중도동</a><em>(0)</em></li>
# <li><a class="NPI=a:area,r:33,i:4211010400" href="#" onclick="nhn.article.common.moveArticle({'cortarNo':4211010400});return false;">중앙로1가</a><em>(0)</em></li>
# <li><a class="NPI=a:area,r:34,i:4211010500" href="#" onclick="nhn.article.common.moveArticle({'cortarNo':4211010500});return false;">중앙로2가</a><em>(0)</em></li>
# <li><a class="NPI=a:area,r:35,i:4211010600" href="#" onclick="nhn.article.common.moveArticle({'cortarNo':4211010600});return false;">중앙로3가</a><em>(0)</em></li>
# <li><a class="NPI=a:area,r:36,i:4211012600" href="#" onclick="nhn.article.common.moveArticle({'cortarNo':4211012600});return false;">칠전동</a><em>(3)</em></li>
# <li><a class="NPI=a:area,r:37,i:4211012300" href="#" onclick="nhn.article.common.moveArticle({'cortarNo':4211012300});return false;">퇴계동</a><em>(22)</em></li>
# <li><a class="NPI=a:area,r:38,i:4211011200" href="#" onclick="nhn.article.common.moveArticle({'cortarNo':4211011200});return false;">효자동</a><em>(7)</em></li>
# <li><a class="NPI=a:area,r:39,i:4211012000" href="#" onclick="nhn.article.common.moveArticle({'cortarNo':4211012000});return false;">후평동</a><em>(32)</em></li>
# </ul>
# </div>
# </div>
# <!--[if gte IE 9]><!-->
# <div class="btn_layer"><span class="bg_btn_layer"></span><a class="NPI=a:open" href="#" onclick="nhn.article.common.mapAreaResize('depthAddrNameListDivision'); return false;" tabindex="-1" title="지역리스트 크게 펼치기"><span class="blind _mapAreaResizeText">지역 리스트 크게 펼치기</span></a></div>
# <!--<![endif]-->
# </div>
# </div>
# <div class="map_bar" id="map_bar" style="display: none;"><a href="#" onclick="nhn.stb.map.toggleExpandMap();return false;" tabindex="-1"><img alt="지도확대" src="https://ssl.pstatic.net/static.land/static/service/20181108-2/article/btn_map_down.gif"/></a></div>
# <div class="clear"></div>
# </div>
# <div id="container">
# <div id="content">
# <div class="sale_info" id="depth4Content">
# <fieldset>
# <h2 id="depth4Content_Title" tabindex="0">[춘천시]</h2>
# <!--	<ul id="depth4Tab" class="tab_sale_detail NE=a:tab">-->
# <!--		 선택된 리스트의 li에는 'on' 클래스 추가, 이미지 파일명에는 _on 추가 -->
# <!--		<li class="on NPI=a:article" id="depth4Tab0" onClick="javascript:nhn.article.common.dvsnArticleTab(); return false;"><a href="#"><img src="https://ssl.pstatic.net/static.land/static/service/20181108-2/article/blank.gif" style="background:url(https://ssl.pstatic.net/static.land/static/service/20181108-2/article/articlelist_20120109.gif) -80px -150px no-repeat;" alt="매물" width="78" height="33"></a></li>-->
# <!-- -->
# <!--			<li class=" NPI=a:trend" id="depth4Tab1" onClick="javascript:nhn.article.common.dvsnPriceInfoTab(); return false;"><a href="#"><img src="https://ssl.pstatic.net/static.land/static/service/20181108-2/article/blank.gif" style="background:url(https://ssl.pstatic.net/static.land/static/service/20181108-2/article/articlelist_20120109.gif) 0 -190px no-repeat;" alt="시세" width="88" height="33"></a></li>-->
# <!-- -->
# <!--		<li class=" NPI=a:news" id="depth4Tab4" onClick="javascript:nhn.article.common.dvsnNewsTab(); return false;"><a href="#"><img src="https://ssl.pstatic.net/static.land/static/service/20181108-2/article/blank.gif" style="background:url(https://ssl.pstatic.net/static.land/static/service/20181108-2/article/articlelist_20120109.gif) -180px -160px no-repeat;" alt="뉴스" width="77" height="33"></a></li>-->
# <!--	</ul>-->
# <ul class="tab_sale_detail NE=a:tab" id="depth4Tab">
# <li class="w66 on"><a class="NPI=a:article" href="javascript:void(nhn.article.common.dvsnArticleTab());" title="매물">매물<span class="ico_opentab"></span></a></li>
# <li class="w66"><a class="NPI=a:trend" href="javascript:void(nhn.article.common.dvsnPriceInfoTab());" title="시세">시세</a></li>
# <li class="w66"><a class="NPI=a:news" href="javascript:void(nhn.article.common.dvsnNewsTab());" title="뉴스">뉴스</a></li>
# </ul>
# <div id="depth4Tab0Content">
# <form class="NE=a:pfb" method="post" name="filterForm">
# <div class="list_option_v list_option_v2 list_option_v3">
# <div class="lst_bg">
# <div class="lst_type">
# <dl>
# <dt tabindex="0">거래종류</dt>
# <dd>
# <ul class="type" id="tabDepth4DealCateList">
# <li>
# <input checked="" class="NPI=a:all list_trad_tp" id="sale4_type1" name="secondTradeTypeSelect" type="radio" value=""/>
# <label for="sale4_type1">전체</label>
# </li>
# <li>
# <input class="NPI=a:sale list_trad_tp" id="sale4_type2" name="secondTradeTypeSelect" type="radio" value="A1"/>
# <label for="sale4_type2">매매</label>
# </li>
# <li>
# <input class="NPI=a:rent list_trad_tp" id="sale4_type3" name="secondTradeTypeSelect" type="radio" value="B1"/>
# <label for="sale4_type3">전세</label>
# </li>
# <li>
# <input class="NPI=a:monthly list_trad_tp" id="sale4_type4" name="secondTradeTypeSelect" type="radio" value="B2"/>
# <label for="sale4_type4">월세</label>
# </li>
# <li>
# <input class="list_trad_tp" id="sale4_type5" name="secondTradeTypeSelect" type="radio" value="B3"/>
# <label for="sale4_type5">단기임대</label>
# </li>
# </ul>
# </dd>
# <dt tabindex="0">매물종류</dt>
# <dd>
# <ul class="type3" id="secondHscpTypeList">
# <li class="NPI=a:apt">
# <input checked="checked" class="_hscp_type_checkbox_" id="second_hscp_type_A01" name="secondHscpTypeSelect" type="checkbox" value="A01"/><label class="_hscp_type_ on" for="second_hscp_type_A01">아파트</label>
# </li>
# <li class="NPI=a:abs">
# <input checked="checked" class="_hscp_type_checkbox_" id="second_hscp_type_A03" name="secondHscpTypeSelect" type="checkbox" value="A03"/><label class="_hscp_type_ on" for="second_hscp_type_A03">주상복합</label>
# </li>
# <li class="NPI=a:rba">
# <input checked="checked" class="_hscp_type_checkbox_" id="second_hscp_type_A04" name="secondHscpTypeSelect" type="checkbox" value="A04"/><label class="_hscp_type_ on" for="second_hscp_type_A04">재건축</label>
# </li>
# </ul>
# </dd>
# </dl>
# </div>
# <div class="lst_type2">
# <dl>
# <dt id="prc2FilterTitle" style="display:none;" tabindex="0">보증금</dt>
# <dd id="prc2FilterLayer" style="display:none;">
# <div class="jselectbox-applied filter" id="prc2Filter">
# <select class="jselectbox-source" title="금액 범위 선택">
# <option value="_">전체</option>
# <option value="0_1000">1천만이하</option>
# <option value="1000_5000">1~5천만</option>
# <option value="5000_10000">5천만~1억</option>
# <option value="10000_30000">1억~3억</option>
# <option value="30000_">3억이상</option>
# <option value="self">직접입력</option>
# </select>
# <div class="jselectbox-box" style="width:79px;">
# <div class="jselectbox-label">전체</div>
# </div>
# <div class="jselectbox-layer">
# <div class="jselectbox-list"></div>
# </div>
# </div>
# <input class="input_text" exfnc="number:txt" id="minWrrntFilterText" maxlength="6" onfocus="prc2FilterList.setValue('self');" title="가격범위 시작(만원)" type="text" value=""/>
# <span class="unit unit2">~</span>
# <input class="input_text" exfnc="number:txt" id="maxWrrntFilterText" maxlength="6" onfocus="prc2FilterList.setValue('self');" title="가격범위 종료(만원)" type="text" value=""/>
# <span class="unit">만원</span>
# </dd>
# <dt id="prc1FilterTitle" style="display:none;" tabindex="0">가격</dt>
# <dd id="prc1FilterLayer" style="display:none;">
# <div class="jselectbox-applied filter" id="prc1Filter">
# <select class="jselectbox-source" title="금액 범위 선택">
# <option value="_">전체</option>
# <option value="0_5000">5천만이하</option>
# <option value="5000_10000">5천만~1억</option>
# <option value="10000_30000">1억~3억</option>
# <option value="30000_60000">3억~6억</option>
# <option value="60000_">6억이상</option>
# <option value="self">직접입력</option>
# </select>
# <div class="jselectbox-box" style="width:79px;">
# <div class="jselectbox-label">전체</div>
# </div>
# <div class="jselectbox-layer">
# <div class="jselectbox-list"></div>
# </div>
# </div>
# <input class="input_text" exfnc="number:txt" id="minPrc1FilterText" maxlength="6" onfocus="prc1FilterList.setValue('self');" title="가격범위 시작(만원)" type="text" value=""/>
# <span class="unit unit2">~</span>
# <input class="input_text" exfnc="number:txt" id="maxPrc1FilterText" maxlength="6" onfocus="prc1FilterList.setValue('self');" title="가격범위 종료(만원)" type="text" value=""/>
# <span class="unit">만원</span>
# </dd>
# <dt id="prc4FilterTitle" style="display:;" tabindex="0">가격</dt>
# <dd id="prc4FilterLayer" style="display:;">
# <div class="jselectbox-applied filter" id="prc4Filter">
# <select class="jselectbox-source" title="금액 범위 선택">
# <option value="_">전체</option>
# <option value="0_10000">1억이하</option>
# <option value="10000_30000">1억~3억</option>
# <option value="30000_60000">3억~6억</option>
# <option value="60000_90000">6억~9억</option>
# <option value="90000_">9억이상</option>
# <option value="self">직접입력</option>
# </select>
# <div class="jselectbox-box" style="width:79px;">
# <div class="jselectbox-label">전체</div>
# </div>
# <div class="jselectbox-layer">
# <div class="jselectbox-list"></div>
# </div>
# </div>
# <input class="input_text" exfnc="number:txt" id="minPrc4FilterText" maxlength="6" onfocus="prc4FilterList.setValue('self');" title="가격범위 시작(만원)" type="text" value=""/>
# <span class="unit unit2">~</span>
# <input class="input_text" exfnc="number:txt" id="maxPrc4FilterText" maxlength="6" onfocus="prc4FilterList.setValue('self');" title="가격범위 종료(만원)" type="text" value=""/>
# <span class="unit">만원</span>
# </dd>
# <dt>면적</dt>
# <dd class="area">
# <div class="jselectbox-applied filter" id="spcFilter">
# <select class="jselectbox-source" title="면적 범위 선택">
# <option value="_">전체</option>
# <option value="0_66">0~66</option>
# <option value="66_99">66~99</option>
# <option value="99_132">99~132</option>
# <option value="132_165">132~165</option>
# <option value="165_198">165~198</option>
# <option value="198_330">198~330</option>
# <option value="330_991">330~991</option>
# <option value="self">직접입력</option>
# </select>
# <div class="jselectbox-box" style="width:79px;">
# <div class="jselectbox-label">전체</div>
# </div>
# <div class="jselectbox-layer">
# <div class="jselectbox-list"></div>
# </div>
# </div>
# <input class="input_text" exfnc="number:txt" id="minSpcFilterText" maxlength="4" onfocus="spcFilterList.setValue('self');" title="가격범위 시작(제곱미터)" type="text" value=""/>
# <span class="unit unit2">~</span>
# <input class="input_text" exfnc="number:txt" id="maxSpcFilterText" maxlength="4" onfocus="spcFilterList.setValue('self');" title="가격범위 종료(제곱미터)" type="text" value=""/>
# <span class="unit">㎡</span>
# </dd>
# <dt id="prc3FilterTitle" style="display:none;">월세</dt>
# <dd id="prc3FilterLayer" style="display:none;">
# <div class="jselectbox-applied filter" id="prc3Filter">
# <select class="jselectbox-source" title="금액 범위 선택">
# <option value="_">전체</option>
# <option value="0_30">30만이하</option>
# <option value="30_50">30~50만</option>
# <option value="50_100">50만~100만</option>
# <option value="100_200">100만~200만</option>
# <option value="200_">200만이상</option>
# <option value="self">직접입력</option>
# </select>
# <div class="jselectbox-box" style="width:79px;">
# <div class="jselectbox-label">전체</div>
# </div>
# <div class="jselectbox-layer">
# <div class="jselectbox-list"></div>
# </div>
# </div>
# <input class="input_text" exfnc="number:txt" id="minLeaseFilterText" maxlength="6" onfocus="prc3FilterList.setValue('self');" title="가격범위 시작(만원)" type="text" value=""/>
# <span class="unit unit2">~</span>
# <input class="input_text" exfnc="number:txt" id="maxLeaseFilterText" maxlength="6" onfocus="prc3FilterList.setValue('self');" title="가격범위 종료(만원)" type="text" value=""/>
# <span class="unit">만원</span>
# </dd>
# <dt id="rentFilterTitle" style="display:none;">계약기간</dt>
# <dd class="" id="rentFilterLayer" style="display:none;">
# <input class="input_text" exfnc="number:txt" id="rentFilterText" maxlength="6" title="계약기간" type="hidden" value=""/>
# <div class="jselectbox-applied filter" id="rentFilter">
# <select class="jselectbox-source" style="width: 79px; overflow-x: hidden;" title="계약기간">
# <option value="_">전체</option>
# <option value="1">1개월</option>
# <option value="3">3개월</option>
# <option value="6">6개월</option>
# <option value="12">12개월</option>
# <option value="24">24개월</option>
# </select>
# <div class="jselectbox-box" style="width: 79px; overflow-x: hidden;">
# <div class="jselectbox-label">전체</div>
# </div>
# <div class="jselectbox-layer">
# <div class="jselectbox-list"></div>
# </div>
# </div>
# <span class="unit">이내</span>
# </dd>
# <dt tabindex="0">역세권</dt>
# <dd class="sub">
# <div class="jselectbox-applied filter" id="subDistFilter">
# <select class="jselectbox-source" title="역 기준 반경">
# <option value="_">-</option>
# <option value="100">100m</option>
# <option value="300">300m</option>
# <option value="500">500m</option>
# <option value="1000">1km</option>
# </select>
# <div class="jselectbox-box" style="width:53px;">
# <div class="jselectbox-label">-</div>
# </div>
# <div class="jselectbox-layer">
# <div class="jselectbox-list"></div>
# </div>
# </div>
# <span class="unit">이내</span>
# </dd>
# <dt class="date" tabindex="0">입주일</dt>
# <dd class="date">
# <div class="jselectbox-applied filter" id="mviDateFilter">
# <select class="jselectbox-source" title="입주일">
# <option value="_">전체</option>
# <option value="1">1년</option>
# <option value="2">2년</option>
# <option value="3">3년</option>
# <option value="5">5년</option>
# <option value="10">10년</option>
# <option value="15">15년</option>
# </select>
# <div class="jselectbox-box" style="width:49px;">
# <div class="jselectbox-label">전체</div>
# </div>
# <div class="jselectbox-layer">
# <div class="jselectbox-list"></div>
# </div>
# </div>
# <span class="unit">이내</span>
# </dd>
# <dt tabindex="0">세대수</dt>
# <dd>
# <div class="jselectbox-applied filter" id="hsehCntFilter">
# <select class="jselectbox-source" title="세대수">
# <option value="_">전체</option>
# <option value="300">300세대</option>
# <option value="500">500세대</option>
# <option value="1000">1000세대</option>
# <option value="1500">1500세대</option>
# <option value="2000">2000세대</option>
# <option value="2500">2500세대</option>
# </select>
# <div class="jselectbox-box" style="width:79px;">
# <div class="jselectbox-label">전체</div>
# </div>
# <div class="jselectbox-layer">
# <div class="jselectbox-list"></div>
# </div>
# </div>
# <span class="unit">이상</span>
# </dd>
# <dt tabindex="0">평균관리비</dt>
# <dd>
# <div class="jselectbox-applied filter" id="mnexFilter">
# <select class="jselectbox-source" title="평균관리비">
# <option value="_">전체</option>
# <option value="0:10">10만원미만</option>
# <option value="10:20">10~20만원</option>
# <option value="30:40">30~40만원</option>
# <option value="40:50">40~50만원</option>
# <option value="50:60">50~60만원</option>
# <option value="60:70">60~70만원</option>
# <option value="70:0">70만원이상</option>
# </select>
# <div class="jselectbox-box" style="width:79px;">
# <div class="jselectbox-label">전체</div>
# </div>
# <div class="jselectbox-layer">
# <div class="jselectbox-list"></div>
# </div>
# </div>
# </dd>
# </dl>
# </div>
# <div class="list_option_btn_area">
# <a class="list_option_btn NPI=a:reset" href="#" onclick="filterReset(); return false;"><img alt="초기화" height="24" src="https://ssl.pstatic.net/static.land/static/service/20181108-2/article/blank.gif" style="background:url(https://ssl.pstatic.net/static.land/static/service/20181108-2/article/articlelist.gif) -130px -591px no-repeat;" width="70"/></a>
# <a class="list_option_btn NPI=a:search" href="#" onclick="filterSubmit(); return false;"><img alt="조회하기" height="24" src="https://ssl.pstatic.net/static.land/static/service/20181108-2/article/blank.gif" style="background:url(https://ssl.pstatic.net/static.land/static/service/20181108-2/article/articlelist.gif) -190px -370px no-repeat;" width="74"/></a>
# </div>
# </div>
# </div>
# </form>
# <!--시군구/읍면동(공동)-->
# <div style="position: relative; z-index: 10">
# <!-- 단지매물 템플릿 START -->
# <h3 class="ti NE=a:cpm">
# <div class="inner">
# <strong tabindex="0">확인매물</strong>
# <span class="btn_layer">
# <a class="NPI=a:help" href="javascript:void($Element($('cfmatcl_tooltip')).toggle());"><img alt="" height="14" src="https://ssl.pstatic.net/static.land/static/service/20120807/article/blank.gif" style="background:url(https://ssl.pstatic.net/static.land/static/service/20181108-2/article/articlelist.gif) -20px -50px no-repeat;" width="14"/></a>
# <span class="layer" id="cfmatcl_tooltip" style="display: none;" tabindex="0">
# <span class="arw"><img alt="" height="6" src="https://ssl.pstatic.net/static.land/static/service/20120807/article/blank.gif" style="background:url(https://ssl.pstatic.net/static.land/static/service/20181108-2/article/articlelist.gif) -50px -20px no-repeat;" width="9"/></span>
# <span class="tit">확인매물</span>
# <span class="tx">집주인(의뢰인)의 거래 의사 확인 후 등록된 매물입니다.</span>
# <div class="guide_box">
# <span class="ico_site">현장확인</span>
# <p class="tx">매물검증센터에서 매물현장을 직접 방문하여 <br/>집주인(의뢰인)에게 직접 확인한 매물입니다.</p>
# </div>
# <div class="guide_box">
# <span class="ico_owner1">집주인</span>
# <p class="tx">실명인증 한 집주인(소유자)이 직접 확인한 매물입니다.</p>
# </div>
# <a class="btn_detail" href="http://m.blog.naver.com/land_admin/221008518772" target="_blank">자세히보기</a>
# <div class="btn_close NPI=a:helpclose"><img alt="닫기" height="9" onclick="$Element($('cfmatcl_tooltip')).hide();" src="https://ssl.pstatic.net/static.land/static/service/20181108-2/article/blank.gif" style="background:url(https://ssl.pstatic.net/static.land/static/service/20181108-2/article/articlelist.gif) -80px -60px no-repeat;" tabindex="0" width="10"/></div>
# </span>
# </span>
# <span class="filter_area">
# <a href="#" onclick="nhn.article.sector.setMapValue();nhn.article.common.refresh({cmplYn:1});return false;"><label class="filter_label" for="_saleFilter">거래완료 매물 포함</label><input class="filter_checkbox" id="_saleFilter" name="" type="checkbox" value=""/></a>
# </span>
# </div>
# <ul class="a_sort">
# <li>
# <a class="NPI=a:sortbyranking rk on" href="#" onclick="nhn.article.sector.setMapValue();nhn.article.common.refresh({articleOrderCode:10});return false;">랭킹순<span class="layer" style="font-weight:normal;'"><strong class="tit">랭킹순</strong><span class="tx" style="color:#8f8f8f;"><em>매물 정보의 진정성을 점수화하여 높은 순으로 정렬</em>매물 정보의 진정성은 네이버 부동산의 내부 정책에<br/>따라 산정됩니다.</span></span></a>
# <span class="bar">|</span>
# </li>
# <li>
# <a class="NPI=a:sortbydate" href="#" onclick="nhn.article.sector.setMapValue();nhn.article.common.refresh({articleOrderCode:-11});return false;">
#
# 				확인매물일자순</a><span class="bar">|</span>
# </li>
# <li>
# <a class="NPI=a:sortbyarea" href="#" onclick="nhn.article.sector.setMapValue();nhn.article.common.refresh({articleOrderCode:-1});return false;">
#
# 				면적순</a><span class="bar">|</span>
# </li>
# <li>
# <a class="NPI=a:sortbyprice" href="#" onclick="nhn.article.sector.setMapValue();nhn.article.common.refresh({articleOrderCode:-3});return false;">
#
# 				가격순</a>
# </li>
# </ul>
# </h3>
# <!-- width:680px -->
# <table cellspacing="0" class="sale_list _tb_site_img NE=a:cpm" summary="확인매물 리스트">
# <!--일반 시군구/읍면동 리스팅시-->
# <caption class="blind_caption">확인 매물</caption>
# <colgroup>
# <col style="width:35px"/>
# <col style="width:57px"/>
# <col style="width:50px"/>
# <col style="width:55px"/>
# <col style="width:158px"/>
# <col style="width:75px"/>
# <col style="width:50px"/>
# <col style="width:70px"/>
# <col style="width:"/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col"><span class="pl4">거래</span></th>
# <th scope="col">종류</th>
# <th scope="col">확인일자</th>
# <th scope="col"> <span class="blind">현장확인 사진</span></th>
# <th scope="col">매물명</th>
# <th scope="col">
#
#
# 						면적(㎡)
#
#
#
# 		</th>
# <th scope="col">층</th>
# <th class="align_r" scope="col">매물가(만원)</th>
# <th scope="col">연락처</th></tr>
# </thead>
# <tbody>
# <tr class="evennum _trow_1902555265">
# <td class="sale_type bottomline" rowspan="2">
# <div class="inner pl4" tabindex="0">매매</div>
# </td>
# <td class="sale_type2 bottomline" rowspan="2" tabindex="0"><div class="inner" style="padding:0;">아파트</div></td>
# <td class="bottomline" rowspan="2">
# <div class="inner inner_mark">
# <span class="mark4" title="확인한지 1개월 이내인 매물"><img alt="확인한지 1개월 이내인 매물" height="15" src="https://ssl.pstatic.net/static.land/static/service/20181108-2/article/blank.gif" style="background:url(https://ssl.pstatic.net/static.land/static/service/20181108-2/article/articlelist.gif) -100px -130px no-repeat;" width="48"/>19.01.31.</span>
# </div>
# </td>
# <td class="align_l name" colspan="2">
# <div class="inner">
# <span class="ico_owner1">집주인</span>
# <a class="NPI=a:list,r:1,i:1902555265 sale_title" href="#" onclick="nhn.article.common.moveArticleDetail('1902555265','A01','A01','A1', 'SERVE','false');return false;" title="춘천두산위브">춘천두산위브</a>
# <span class="btn_naverlink">
# <a class="NPI=a:listnew,r:1,i:1902555265" href="/article/articleDetailInfo.nhn?atclNo=1902555265&amp;atclRletTypeCd=A01&amp;rletTypeCd=A01&amp;tradeTypeCd=A1" target="_blank">네이버부동산에서 보기</a>
# </span>
# </div>
# </td>
# <td class="num" onmouseout="$Element($$.getSingle('div.inner',this)).css('zIndex', '0'); $Element($$.getSingle('div.rate_layer',this)).hide();" onmouseover="$Element($$.getSingle('div.inner',this)).css('zIndex', '10');$Element($$.getSingle('div.rate_layer',this)).show();">
# <div class="inner" tabindex="0">
# 				107C/84
# 				<div class="rate_layer" style="display:none;">
# <div class="layer">
# <p class="calc_area">
# 							공급면적 107.5㎡
# 							<br/>
#
# 							전용면적 84.96㎡
# 							<br/>
# </p>
# </div>
# </div>
# </div>
# </td>
# <td class="num2"><div class="inner" tabindex="0"><span>7/15</span></div></td>
# <td class="num align_r">
# <div class="inner">
# <strong title="23,500">23,500</strong>
# </div>
# </td>
# <td class="contact bottomline" rowspan="2">
# <div class="inner">
# <a href="javascript:nhn.article.common.moveRealtorPage('doosan2030', null, true)">
# <span class="title_agent" title="두산공인중개사사무소">
# 							두산공인중개사사무소
# 						</span>
# <span class="tel">033-241-8959</span>
# </a>
# </div>
# </td>
# </tr>
# <tr class="evennum _trow_1902555265">
# <td class="desc bottomline" colspan="5">
# <div class="inner">
# <span class="txt" title="84C 확장형">84C 확장형</span>
# <span class="txt_a">
# <a class="tx NPI=a:cpsource" href="http://www.serve.co.kr/naver/rd.asp?UID=1902555265" target="_blank">부동산써브</a>
# </span>
# </div>
# </td>
# </tr>
# <tr class="_trow_1902554736">
# <td class="sale_type bottomline" rowspan="2">
# <div class="inner pl4" tabindex="0">매매</div>
# </td>
# <td class="sale_type2 bottomline" rowspan="2" tabindex="0"><div class="inner" style="padding:0;">아파트</div></td>
# <td class="bottomline" rowspan="2">
# <div class="inner inner_mark">
# <span class="mark4" title="확인한지 1개월 이내인 매물"><img alt="확인한지 1개월 이내인 매물" height="15" src="https://ssl.pstatic.net/static.land/static/service/20181108-2/article/blank.gif" style="background:url(https://ssl.pstatic.net/static.land/static/service/20181108-2/article/articlelist.gif) -100px -130px no-repeat;" width="48"/>19.01.31.</span>
# </div>
# </td>
# <td class="align_l name" colspan="2">
# <div class="inner">
# <span class="ico_owner1">집주인</span>
# ...
# 													$Element(prc2FilterList.getSelectElement()).delegate('change', 'SELECT', function(oEvent) {
# 														var prcs = oEvent.element.value.split("_");
# 														if(oEvent.element.value == "self") {
# 															$Element($("minWrrntFilterText")).text("");
# 															$Element($("maxWrrntFilterText")).text("");
# 															$("minWrrntFilterText").focus();
# 														} else {
# 															if(prcs) {
# 																if(prcs[0]) {
# 																	$Element($("minWrrntFilterText")).text(prcs[0]);
# 																} else {
# 																	$Element($("minWrrntFilterText")).text("");
# 																}
# 																if(prcs[1]) {
# 																	$Element($("maxWrrntFilterText")).text(prcs[1]);
# 																} else {
# 																	$Element($("maxWrrntFilterText")).text("");
# 																}
# 															} else {
# 																$Element($("minWrrntFilterText")).text("");
# 																$Element($("maxWrrntFilterText")).text("");
# 															}
# 														}
# 														clickcr(oEvent.element, "pfb.price2", oEvent.element.value, prc2FilterList.getSelectedIndex()+1);
# 													});
# 												</script>
# <script>
# 													var prc1FilterList = new jindo.SelectBox($("prc1Filter"), {  sClassPrefix : "jselectbox-", nWidth : 79, nHeight : 172 });
# 													if(jsonPageData.minPrc != '' || jsonPageData.maxPrc != '') prc1FilterList.setValue('self');
# 													$Element(prc1FilterList.getSelectElement()).delegate('change', 'SELECT', function(oEvent) {
# 														var prcs = oEvent.element.value.split("_");
# 														if(oEvent.element.value == "self") {
# 															$Element($("minPrc1FilterText")).text("");
# 															$Element($("maxPrc1FilterText")).text("");
# 															$("minPrc1FilterText").focus();
# 														} else {
# 															if(prcs) {
# 																if(prcs[0]) {
# 																	$Element($("minPrc1FilterText")).text(prcs[0]);
# 																} else {
# 																	$Element($("minPrc1FilterText")).text("");
# 																}
# 																if(prcs[1]) {
# 																	$Element($("maxPrc1FilterText")).text(prcs[1]);
# 																} else {
# 																	$Element($("maxPrc1FilterText")).text("");
# 																}
# 															} else {
# 																$Element($("minPrc1FilterText")).text("");
# 																$Element($("maxPrc1FilterText")).text("");
# 															}
# 														}
# 														clickcr(oEvent.element, "pfb.price1", oEvent.element.value, prc1FilterList.getSelectedIndex()+1);
# 													});
# 												</script>
# <script>
# 													var prc4FilterList = new jindo.SelectBox($("prc4Filter"), {  sClassPrefix : "jselectbox-", nWidth : 79, nHeight : 172 });
# 													if(jsonPageData.minPrc != '' || jsonPageData.maxPrc != '') prc4FilterList.setValue('self');
# 													$Element(prc4FilterList.getSelectElement()).delegate('change', 'SELECT', function(oEvent) {
# 														var prcs = oEvent.element.value.split("_");
# 														if(oEvent.element.value == "self") {
# 															$Element($("minPrc4FilterText")).text("");
# 															$Element($("maxPrc4FilterText")).text("");
# 															$("minPrc4FilterText").focus();
# 														} else {
# 															if(prcs) {
# 																if(prcs[0]) {
# 																	$Element($("minPrc4FilterText")).text(prcs[0]);
# 																} else {
# 																	$Element($("minPrc4FilterText")).text("");
# 																}
# 																if(prcs[1]) {
# 																	$Element($("maxPrc4FilterText")).text(prcs[1]);
# 																} else {
# 																	$Element($("maxPrc4FilterText")).text("");
# 																}
# 															} else {
# 																$Element($("minPrc4FilterText")).text("");
# 																$Element($("maxPrc4FilterText")).text("");
# 															}
# 														}
# 														clickcr(oEvent.element, "pfb.price1", oEvent.element.value, prc4FilterList.getSelectedIndex()+1);
# 													});
# 												</script>
# <script>
# 											var spcFilterList = new jindo.SelectBox($("spcFilter"), {  sClassPrefix : "jselectbox-", nWidth : 79, nHeight : 172 });
# 											if(jsonPageData.minSpc != '' || jsonPageData.maxSpc != '') spcFilterList.setValue('self');
# 											$Element(spcFilterList.getSelectElement()).delegate('change', 'SELECT', function(oEvent) {
# 												var spcs = oEvent.element.value.split("_");
# 												if(oEvent.element.value == "self") {
# 													$Element($("minSpcFilterText")).text("");
# 													$Element($("maxSpcFilterText")).text("");
# 													$("minSpcFilterText").focus();
# 												} else {
# 													if(spcs) {
# 														if(spcs[0]) {
# 															$Element($("minSpcFilterText")).text(spcs[0]);
# 														} else {
# 															$Element($("minSpcFilterText")).text("");
# 														}
# 														if(spcs[1]) {
# 															$Element($("maxSpcFilterText")).text(spcs[1]);
# 														} else {
# 															$Element($("maxSpcFilterText")).text("");
# 														}
# 													} else {
# 														$Element($("minSpcFilterText")).text("");
# 														$Element($("maxSpcFilterText")).text("");
# 													}
# 												}
# 												clickcr(oEvent.element, "pfb.area", oEvent.element.value, spcFilterList.getSelectedIndex()+1);
# 											});
# 										</script>
# <script>
# 											var prc3FilterList = new jindo.SelectBox($("prc3Filter"), {  sClassPrefix : "jselectbox-", nWidth : 79, nHeight : 172 });
# 											if(jsonPageData.minLease != '' || jsonPageData.maxLease != '') prc3FilterList.setValue('self');
# 											$Element(prc3FilterList.getSelectElement()).delegate('change', 'SELECT', function(oEvent) {
# 												var prcs = oEvent.element.value.split("_");
# 												if(oEvent.element.value == "self") {
# 													$Element($("minLeaseFilterText")).text("");
# 													$Element($("maxLeaseFilterText")).text("");
# 													$("minLeaseFilterText").focus();
# 												} else {
# 													if(prcs) {
# 														if(prcs[0]) {
# 															$Element($("minLeaseFilterText")).text(prcs[0]);
# 														} else {
# 															$Element($("minLeaseFilterText")).text("");
# 														}
# 														if(prcs[1]) {
# 															$Element($("maxLeaseFilterText")).text(prcs[1]);
# 														} else {
# 															$Element($("maxLeaseFilterText")).text("");
# 														}
# 													} else {
# 														$Element($("minLeaseFilterText")).text("");
# 														$Element($("maxLeaseFilterText")).text("");
# 													}
# 												}
# 												clickcr(oEvent.element, "pfb.price3", oEvent.element.value, prc3FilterList.getSelectedIndex()+1);
# 											});
# 										</script>
# <script>
# 										var rentFilterList = new jindo.SelectBox($("rentFilter"), {  sClassPrefix : "jselectbox-", nWidth : 79, nHeight : 172 });
# 										var rentValue = '';
# 										if(rentValue!='' && rentValue !=null) rentFilterList.setValue(rentValue);
# 										$Element(rentFilterList.getSelectElement()).delegate('change', 'SELECT', function(oEvent) {
# 											$Element($("rentFilterText")).text(oEvent.element.value);
# 											clickcr(oEvent.element, "", oEvent.element.value, rentFilterList.getSelectedIndex()+1);
# 										});
# 									</script>
# <script>
# 										var subDistFilterList = new jindo.SelectBox($("subDistFilter"), {  sClassPrefix : "jselectbox-", nWidth : 53, nHeight : 172 });
# 										if (jsonPageData.subDist) subDistFilterList.setValue(jsonPageData.subDist);
# 										$Element(subDistFilterList.getSelectElement()).delegate('change', 'SELECT', function(oEvent) {
# 											clickcr(oEvent.element, "pfb.subway", oEvent.element.value, subDistFilterList.getSelectedIndex()+1);
# 										});
# 									</script>
# <script>
# 										var mviDateFilterList = new jindo.SelectBox($("mviDateFilter"), {  sClassPrefix : "jselectbox-", nWidth : 49, nHeight : 172 });
# 										if (jsonPageData.mviDate) mviDateFilterList.setValue(jsonPageData.mviDate);
# 										$Element(mviDateFilterList.getSelectElement()).delegate('change', 'SELECT', function(oEvent) {
# 											clickcr(oEvent.element, "pfb.movein", oEvent.element.value, mviDateFilterList.getSelectedIndex()+1);
# 										});
# 									</script>
# <script>
# 										var hsehCntFilterList = new jindo.SelectBox($("hsehCntFilter"), {  sClassPrefix : "jselectbox-", nWidth : 79, nHeight : 172 });
# 										if (jsonPageData.hsehCnt) hsehCntFilterList.setValue(jsonPageData.hsehCnt);
# 										$Element(hsehCntFilterList.getSelectElement()).delegate('change', 'SELECT', function(oEvent) {
# 											clickcr(oEvent.element, "pfb.hhd", oEvent.element.value, hsehCntFilterList.getSelectedIndex()+1);
# 										});
# 									</script>
# <script>
# 										var mnexFilterList = new jindo.SelectBox($("mnexFilter"), {  sClassPrefix : "jselectbox-", nWidth : 79, nHeight : 172 });
# 										if (jsonPageData.mnex) mnexFilterList.setValue(jsonPageData.mnex);
# 										$Element(mnexFilterList.getSelectElement()).delegate('change', 'SELECT', function(oEvent) {
# 											clickcr(oEvent.element, "pfb.hhd", oEvent.element.value, mnexFilterList.getSelectedIndex()+1);
# 										});
# 									</script>
# <script>
# 		var cpList = $Json('[{"cpid":"SERVE","cpNm":"부동산써브","cityBnnrExpsYn":"N","dvsnBnnrExpsYn":"Y","hscpBnnrExpsYn":"Y","bnnrUrl":"https://landthumb-phinf.pstatic.net/20170919_129/land_naver_1505806210899c92q7_GIF/serve_banner2.gif","hmpgUrl":"http://www.serve.co.kr/","totExpsAtclPnt":238140,"siteExpsAtclPnt":0,"randomValue":null},{"cpid":"bizmk","cpNm":"매경부동산","cityBnnrExpsYn":"N","dvsnBnnrExpsYn":"Y","hscpBnnrExpsYn":"Y","bnnrUrl":"https://landthumb-phinf.pstatic.net/20140512_50/land_naver_1399871839422bMyCr_GIF/bizmk.gif","hmpgUrl":"http://land.bizmk.kr/","totExpsAtclPnt":161400,"siteExpsAtclPnt":0,"randomValue":null},{"cpid":"DRAPT","cpNm":"닥터아파트","cityBnnrExpsYn":"N","dvsnBnnrExpsYn":"Y","hscpBnnrExpsYn":"Y","bnnrUrl":"https://landthumb-phinf.pstatic.net/20140408_246/land_naver_1396935179859M2evS_GIF/DRAPT.gif","hmpgUrl":"http://naver.drapt.com/","totExpsAtclPnt":104130,"si
erUrl":"http://n.gongsilclub.com/etc/rd.asp","pcBmsInspectPassYn":"Y","pcLinkUse":true},"fine":{"cpId":"fine","cpNm":"","mobileArticleLinkTypeCode":"","mobileArticleLinkUseAtArticleTitle":false,"mobileArticleLinkUseAtCpName":false,"mobileArticleUrl":"","mobileBmsInspectPassYn":"","pcArticleBridgeUrl":"","pcArticleLinkTypeCode":"CPNAMEONLY","pcArticleLinkUseAtArticleTitle":false,"pcArticleLinkUseAtCpName":true,"pcArticleUrl":"http://www.rfine.kr/rd/rd.php?UID=","pcBannerUrl":"http://www.rfine.kr/rd/rd.php","pcBmsInspectPassYn":"Y","pcLinkUse":true},"industry":{"cpId":"industry","cpNm":"","mobileArticleLinkTypeCode":"","mobileArticleLinkUseAtArticleTitle":false,"mobileArticleLinkUseAtCpName":false,"mobileArticleUrl":"","mobileBmsInspectPassYn":"","pcArticleBridgeUrl":"","pcArticleLinkTypeCode":"CPNAMEONLY","pcArticleLinkUseAtArticleTitle":false, ...
# 		var outLinkParam = '?rletTypeNm=%ec%95%84%ed%8c%8c%ed%8a%b8&cortarNo=4211000000';
# 	</script>
# </body>
# </html>

# %% [markdown]
# 페이지를 가져왔으니 여기서 우리가 필요한 정보만 가져와볼까요? 위에 설명드린것 처럼 `ctrl` + 마우스오른쪽클릭 에서 검사버튼을 누르면 개발자도구로 이동할수 있어요.

# %% [markdown]
# ![4-10](../image/4-10.gif)

# %% [markdown]
# 여기서 우리가 필요한 부분의 태그를 가져와봅시다. 아래와 같이 태그를 가져올수 있나요?
# ```html
# #depth4Tab0Content > div > table > tbody > tr:nth-child(1) > td.sale_type.bottomline
# ```
# BeautifulSoup에서는 `nth-child`를 지원하지 않아요. `nth-child`를 `nth-of-type`로 바꿔줍시다.

# %%
# row 값을 가져오기 위한 tbody값 선택
tbody = soup.select('#depth4Tab0Content > div > table > tbody > tr:nth-of-type(1) > td.sale_type.bottomline')
tbody
# Out:
# [<td class="sale_type bottomline" rowspan="2">
#  <div class="inner pl4" tabindex="0">매매</div>
#  </td>]

# %%
tbody[0].text
# Out:
# '\n매매\n'

# %% [markdown]
# 표에서 한개의 셀값만 가져올때는 이렇게 하면 되지만 표 전체의 셀을 가져오려면 두단계 위의 값을 가져와야겠죠? 두단계 위의 값을 가져와봅시다.

# %%
tbody = soup.select('#depth4Tab0Content > div > table > tbody > tr')
tbody
# Out:
# [<tr class="evennum _trow_1902555265">
#  <td class="sale_type bottomline" rowspan="2">
#  <div class="inner pl4" tabindex="0">매매</div>
#  </td>
#  <td class="sale_type2 bottomline" rowspan="2" tabindex="0"><div class="inner" style="padding:0;">아파트</div></td>
#  <td class="bottomline" rowspan="2">
#  <div class="inner inner_mark">
#  <span class="mark4" title="확인한지 1개월 이내인 매물"><img alt="확인한지 1개월 이내인 매물" height="15" src="https://ssl.pstatic.net/static.land/static/service/20181108-2/article/blank.gif" style="background:url(https://ssl.pstatic.net/static.land/static/service/20181108-2/article/articlelist.gif) -100px -130px no-repeat;" width="48"/>19.01.31.</span>
#  </div>
#  </td>
#  <td class="align_l name" colspan="2">
#  <div class="inner">
#  <span class="ico_owner1">집주인</span>
#  <a class="NPI=a:list,r:1,i:1902555265 sale_title" href="#" onclick="nhn.article.common.moveArticleDetail('1902555265','A01','A01','A1', 'SERVE','false');return false;" title="춘천두산위브">춘천두산위브</a>
#  <span class="btn_naverlink">
#  <a class="NPI=a:listnew,r:1,i:1902555265" href="/article/articleDetailInfo.nhn?atclNo=1902555265&amp;atclRletTypeCd=A01&amp;rletTypeCd=A01&amp;tradeTypeCd=A1" target="_blank">네이버부동산에서 보기</a>
#  </span>
#  </div>
#  </td>
#  <td class="num" onmouseout="$Element($$.getSingle('div.inner',this)).css('zIndex', '0'); $Element($$.getSingle('div.rate_layer',this)).hide();" onmouseover="$Element($$.getSingle('div.inner',this)).css('zIndex', '10');$Element($$.getSingle('div.rate_layer',this)).show();">
#  <div class="inner" tabindex="0">
#  				107C/84
#  				<div class="rate_layer" style="display:none;">
#  <div class="layer">
#  <p class="calc_area">
#  							공급면적 107.5㎡
#  							<br/>
#
#  							전용면적 84.96㎡
#  							<br/>
#  </p>
#  </div>
#  </div>
#  </div>
#  </td>
#  <td class="num2"><div class="inner" tabindex="0"><span>7/15</span></div></td>
#  <td class="num align_r">
#  <div class="inner">
#  <strong title="23,500">23,500</strong>
#  </div>
#  </td>
#  <td class="contact bottomline" rowspan="2">
#  <div class="inner">
#  <a href="javascript:nhn.article.common.moveRealtorPage('doosan2030', null, true)">
#  <span class="title_agent" title="두산공인중개사사무소">
#  							두산공인중개사사무소
#  						</span>
#  <span class="tel">033-241-8959</span>
#  </a>
#  </div>
#  </td>
#  </tr>, <tr class="evennum _trow_1902555265">
#  <td class="desc bottomline" colspan="5">
#  <div class="inner">
#  <span class="txt" title="84C 확장형">84C 확장형</span>
#  <span class="txt_a">
#  <a class="tx NPI=a:cpsource" href="http://www.serve.co.kr/naver/rd.asp?UID=1902555265" target="_blank">부동산써브</a>
#  </span>
#  </div>
#  </td>
#  </tr>, <tr class="_trow_1902554736">
#  <td class="sale_type bottomline" rowspan="2">
#  <div class="inner pl4" tabindex="0">매매</div>
#  </td>
#  <td class="sale_type2 bottomline" rowspan="2" tabindex="0"><div class="inner" style="padding:0;">아파트</div></td>
#  <td class="bottomline" rowspan="2">
#  <div class="inner inner_mark">
#  <span class="mark4" title="확인한지 1개월 이내인 매물"><img alt="확인한지 1개월 이내인 매물" height="15" src="https://ssl.pstatic.net/static.land/static/service/20181108-2/article/blank.gif" style="background:url(https://ssl.pstatic.net/static.land/static/service/20181108-2/article/articlelist.gif) -100px -130px no-repeat;" width="48"/>19.01.31.</span>
#  </div>
#  </td>
#  <td class="align_l name" colspan="2">
#  <div class="inner">
#  <span class="ico_owner1">집주인</span>
#  <a class="NPI=a:list,r:2,i:1902554736 sale_title" href="#" onclick="nhn.article.common.moveArticleDetail('1902554736','A01','A01','A1', 'SERVE','false');return false;" title="춘천두산위브">춘천두산위브</a>
#  <span class="btn_naverlink">
#  <a class="NPI=a:listnew,r
000</strong>
#  </div>
#  </td>
#  <td class="contact bottomline" rowspan="2">
#  <div class="inner">
#  <a href="javascript:nhn.article.common.moveRealtorPage('chun0sy', null, true)">
#  <span class="title_agent" title="금탑공인중개사사무소">
#  							금탑공인중개사사무소
#  						</span>
#  <span class="tel">033-254-2454</span>
#  </a>
#  </div>
#  </td>
#  </tr>, <tr class="_trow_1902259133">
#  <td class="desc bottomline" colspan="5">
#  <div class="inner">
#  <span class="txt" title="공기 좋고 조용한 전원 아파트">공기 좋고 조용한 전원 아파트</span>
#  <span class="txt_a">
#  <a class="tx NPI=a:cpsource" href="http://maemul.joinsland.joins.com/naver?UID=1902259133" target="_blank">조인스랜드</a>
#  </span>
#  </div>
#  </td>
#  </tr>, <tr class="evennum _trow_1902270322">
#  <td class="sale_type bottomline" rowspan="2">
#  <div class="inner pl4" tabindex="0">매매</div>
#  </td>
#  <td class="sale_type2 bottomline" rowspan="2" tabindex="0"><div class="inner" style="padding:0;">아파트</div></td>
#  <td class="bottomline" rowspan="2">
#  <div class="inner inner_mark">
#  <span class="mark4" title="확인한지 1개월 이내인 매물"><img alt="확인한지 1개월 이내인 매물" height="15" src="https://ssl.pstatic.net/static.land/static/service/20181108-2/article/blank.gif" style="background:url(https://ssl.pstatic.net/static.land/static/service/20181108-2/article/articlelist.gif) -100px -130px no-repeat;" width="48"/>19.01.28.</span>
#  </div>
#  </td>
#  <td class="align_l name" colspan="2">
#  <div class="inner">
#  <span class="ico_owner1">집주인</span>
#  <a class="NPI=a:list,r:13,i:1902270322 sale_title" href="#" onclick="nhn.article.common.moveArticleDetail('1902270322','A01','A01','A1', 'JOINS','false');return false;" title="e편한세상춘천">e편한세상춘천</a>
#  <span class="btn_naverlink">
#  <a class="NPI=a:listnew,r:13,i:1902270322" href="/article/articleDetailInfo.nhn?atclNo=1902270322&amp;atclRletTypeCd=A01&amp;rletTypeCd=A01&amp;tradeTypeCd=A1" target="_blank">네이버부동산에서 보기</a>
#  </span>
#  </div>
#  </td>
#  <td class="num" onmouseout="$Element($$.getSingle('div.inner',this)).css('zIndex', '0'); $Element($$.getSingle('div.rate_layer',this)).hide();" onmouseover="$Element($$.getSingle('div.inner',this)).css('zIndex', '10');$Element($$.getSingle('div.rate_layer',this)).show();">
#  <div class="inner" tabindex="0">
#  				109A/84
#  				<div class="rate_layer" style="display:none;">
#  <div class="layer">
#  <p class="calc_area">
#  							공급면적 109.9㎡
#  							<br/>
#
#  							전용면적 84.96㎡
#  							<br/>
#  </p>
#  </div>
#  </div>
#  </div>
#  </td>
#  <td class="num2"><div class="inner" tabindex="0"><span>7/18</span></div></td>
#  <td class="num align_r">
#  <div class="inner">
#  <strong title="28,800">28,800</strong>
#  </div>
#  </td>
#  <td class="contact bottomline" rowspan="2">
#  <div class="inner">
#  <a href="javascript:nhn.article.common.moveRealtorPage('chun0sy', null, true)">
#  <span class="title_agent" title="금탑공인중개사사무소">
#  							금탑공인중개사사무소
#  						</span>
#  <span class="tel">033-254-2454</span>
#  </a>
#  </div>
#  </td>
#  </tr>, <tr class="evennum _trow_1902270322">
#  <td class="desc bottomline" colspan="5">
#  <div class="inner">
#  <span class="txt" title="확장형. 앞이 확 틔었음. 전세 끼고 매매">확장형. 앞이 확 틔었음. 전세 끼고 매매</span>
#  <span class="txt_a">
#  <a class="tx NPI=a:cpsource" href="http://maemul.joinsland.joins.com/naver?UID=1902270322" target="_blank">조인스랜드</a>
#  </span>
#  </div>
#  </td>
#  </tr>, <tr class="_trow_1902267636">
#  <td class="sale_type bottomline" rowspan="2">
#  <div class="inner pl4" tabindex="0">매매</div>
#  </td>
#  <td class="sale_type2 bottomline" rowspan="2" tabindex="0"><div class="inner" style="padding:0;">아파트</div></td>
#  <td class="bottomline" rowspan="2">
#  <div class="inner inner_mark">
#  <span class="mark4" title="확인한지 1개월 이내인 매물"><img alt="확인한지 1개월 이내인 매물" height="15" src="https://ssl.pstatic.net/static.land/static/service/20181108-2/article/blank.gif" style="background:url(https://ssl.pstatic.net/static.land/static/service/20181108-2/article/articlelist.gif) -100px -130px no-repeat;" width="48"/>19.01.28.</span>
#  </div>
#  </td>
#  <td class="bottomline _thumb_image" loop_id="p14" rowspan="2">
#  <div class="inner inner_thmb">
#  <div class="thmb" id="imgView_p14">
#  <div _iscppcarticlelinkuseatarticletitle="false" atcl_no="1902267636" atcl_rlet_type_cd="A01" class="thmb_area _thumb_gal_img" img_id="/20190128_37/land_naver_15486508949895MzlY_JPEG/133c9d51e7922.jpg" rlet_type_cd="A01">
#  <img alt="e편한세상춘천 이미지" height="45" src="https://landthumb-phinf.pstatic.net/20190128_37/land_naver_15486508949895MzlY_JPEG/133c9d51e7922.jpg?type=f45_45" width="45"/>
#  <span class="mask NPI=a:thumb,r:14,i:1902267636"></span>
#  </div>
#  </div>
#  <div class="thmb" id="imgListView_p14" style="display: none;">
#  <div class="ly_thmb" style="width:0px">
#  <ul _iscppcarticlelinkuseatarticletitle="false" id="imgUl_p14"></ul>
#  <p class="ly_num"><span id="imgNum_p14">0</span><em>/</em><strong>0</strong></p>
#  </div>
#  </div>
#  </div>
#  </td>
#  <td class="align_l name">
#  <div class="inner">
#  <span class="ico_owner1">집주인</span>
#  <a class="NPI=a:list,r:14,i:1902267636 sale_title" href="#" onclick="nhn.article.common.moveArticleDetail('1902267636','A01','A01','A1', 'JOINS','false');return false;" title="e편한세상춘천">e편한세상춘천</a>
#  <span class="btn_naverlink">
#  <a class="NPI=a:listnew,r:14,i:1902267636" href="/article/articleDetailInfo.nhn?atclNo=1902267636&amp;atclRletTypeCd=A01&amp;rletTypeCd=A01&amp;tradeTypeCd=A1" target="_blank">네이버부동산에서 보기</a>
#  </span>
#  </div>
#  </td>
#  <td class="num" onmouseout="$Element($$.getSingle('div.inner',this)).css('zIndex', '0'); $Element($$.getSingle('div.rate_layer',this)).hide();" onmouseover="$Element($$.getSingle('div.inner',this)).css('zIndex', '10');$Element($$.getSingle('div.rate_layer',this)).show();">
#  <div class="inner" tabindex="0">
#  				99/78
#  				<div class="rate_layer" style="display:none;">
#  <div class="layer">
#  <p class="calc_area">
#  							공급면적 99.75㎡
#  							<br/>
#
#  							전용면적 78.31㎡
#  							<br/>
#  </p>
#  </div>
#  </div>
#  </div>
#  </td>
#  <td class="num2"><div class="inner" tabindex="0"><span>1/18</span></div></td>
#  <td class="num align_r">
#  <div class="inner">
#  <strong title="24,000">24,000</strong>
#  </div>
#  </td>
#  <td class="contact bottomline" rowspan="2">
#  <div class="inner">
#  <a href="javascript:nhn.article.common.moveRealtorPage('chun0sy', null, true)">
#  <span class="title_agent" title="금탑공인중개사사무소">
#  							금탑공인중개사사무소
#  						</span>
#  <span class="tel">033-254-2454</span>
#  </a>
#  </div>
#  </td>
#  </tr>, <tr class="_trow_1902267636">
#  <td class="desc bottomline" colspan="4">
#  <div class="inner">
#  <span class="txt" title="풀옵션으로 리모델링. 전세 안고 매매. 매매가 협상">풀옵션으로 리모델링. 전세 안고 매매. 매매가 협상</span>
#  <span class="txt_a">
#  <a class="tx NPI=a:cpsource" href="http://maemul.joinsland.joins.com/naver?UID=1902267636" target="_blank">조인스랜드</a>
#  </span>
#  </div>
#  </td>
#  </tr>, <tr class="evennum _trow_1902218516">
#  <td class="sale_type bottomline" rowspan="2">
#  <div class="inner pl4" tabindex="0">매매</div>
#  </td>
#  <td class="sale_type2 bottomline" rowspan="2" tabindex="0"><div class="inner" style="padding:0;">아파트</div></td>
#  <td class="bottomline" rowspan="2">
#  <div class="inner inner_mark">
#  <span class="mark4" title="확인한지 1개월 이내인 매물"><img alt="확인한지 1개월 이내인 매물" height="15" src="https://ssl.pstatic.net/static.land/static/service/20181108-2/article/blank.gif" style="background:url(https://ssl.pstatic.net/static.land/static/service/20181108-2/article/articlelist.gif) -100px -130px no-repeat;" width="48"/>19.01

#  <div class="inner">
#  <span class="ico_owner1">집주인</span>
#  <a class="NPI=a:list,r:28,i:1901833169 sale_title" href="#" onclick="nhn.article.common.moveArticleDetail('1901833169','A01','A01','A1', 'SERVE','false');return false;" title="그랜드">그랜드</a>
#  <span class="btn_naverlink">
#  <a class="NPI=a:listnew,r:28,i:1901833169" href="/article/articleDetailInfo.nhn?atclNo=1901833169&amp;atclRletTypeCd=A01&amp;rletTypeCd=A01&amp;tradeTypeCd=A1" target="_blank">네이버부동산에서 보기</a>
#  </span>
#  </div>
#  </td>
#  <td class="num" onmouseout="$Element($$.getSingle('div.inner',this)).css('zIndex', '0'); $Element($$.getSingle('div.rate_layer',this)).hide();" onmouseover="$Element($$.getSingle('div.inner',this)).css('zIndex', '10');$Element($$.getSingle('div.rate_layer',this)).show();">
#  <div class="inner" tabindex="0">
#  				109/84
#  				<div class="rate_layer" style="display:none;">
#  <div class="layer">
#  <p class="calc_area">
#  							공급면적 109.55㎡
#  							<br/>
#
#  							전용면적 84.95㎡
#  							<br/>
#  </p>
#  </div>
#  </div>
#  </div>
#  </td>
#  <td class="num2"><div class="inner" tabindex="0"><span>6/15</span></div></td>
#  <td class="num align_r">
#  <div class="inner">
#  <strong title="20,300">20,300</strong>
#  </div>
#  </td>
#  <td class="contact bottomline" rowspan="2">
#  <div class="inner">
#  <a href="javascript:nhn.article.common.moveRealtorPage('grand--', null, true)">
#  <span class="title_agent" title="그랜드부동산공인중개사사무소">
#  							그랜드부동산공인중개사사무소
#  						</span>
#  <span class="tel">033-264-4289</span>
#  </a>
#  </div>
#  </td>
#  </tr>, <tr class="_trow_1901833169">
#  <td class="desc bottomline" colspan="4">
#  <div class="inner">
#  <span class="txt" title="최근최상급한샘올수리 강력추천">최근최상급한샘올수리 강력추천</span>
#  <span class="txt_a">
#  <a class="tx NPI=a:cpsource" href="http://www.serve.co.kr/naver/rd.asp?UID=1901833169" target="_blank">부동산써브</a>
#  </span>
#  </div>
#  </td>
#  </tr>, <tr class="evennum _trow_1902476592">
#  <td class="sale_type bottomline" rowspan="2">
#  <div class="inner pl4" tabindex="0">매매</div>
#  </td>
#  <td class="sale_type2 bottomline" rowspan="2" tabindex="0"><div class="inner" style="padding:0;">아파트</div></td>
#  <td class="bottomline" rowspan="2">
#  <div class="inner inner_mark">
#  <span class="mark4" title="확인한지 1개월 이내인 매물"><img alt="확인한지 1개월 이내인 매물" height="15" src="https://ssl.pstatic.net/static.land/static/service/20181108-2/article/blank.gif" style="background:url(https://ssl.pstatic.net/static.land/static/service/20181108-2/article/articlelist.gif) -100px -130px no-repeat;" width="48"/>19.01.30.</span>
#  </div>
#  </td>
#  <td class="align_l name" colspan="2">
#  <div class="inner">
#  <a class="NPI=a:list,r:29,i:1902476592 sale_title" href="#" onclick="nhn.article.common.moveArticleDetail('1902476592','A01','A01','A1', 'bizmk','false');return false;" title="동부">동부</a>
#  <span class="btn_naverlink">
#  <a class="NPI=a:listnew,r:29,i:1902476592" href="/article/articleDetailInfo.nhn?atclNo=1902476592&amp;atclRletTypeCd=A01&amp;rletTypeCd=A01&amp;tradeTypeCd=A1" target="_blank">네이버부동산에서 보기</a>
#  </span>
#  </div>
#  </td>
#  <td class="num" onmouseout="$Element($$.getSingle('div.inner',this)).css('zIndex', '0'); $Element($$.getSingle('div.rate_layer',this)).hide();" onmouseover="$Element($$.getSingle('div.inner',this)).css('zIndex', '10');$Element($$.getSingle('div.rate_layer',this)).show();">
#  <div class="inner" tabindex="0">
#  				103/84
#  				<div class="rate_layer" style="display:none;">
#  <div class="layer">
#  <p class="calc_area">
#  							공급면적 103.18㎡
#  							<br/>
#
#  							전용면적 84.96㎡
#  							<br/>
#  </p>
#  </div>
#  </div>
#  </div>
#  </td>
#  <td class="num2"><div class="inner" tabindex="0"><span>11/15</span></div></td>
#  <td class="num align_r">
#  <div class="inner">
#  <strong title="14,900">14,900</strong>
#  </div>
#  </td>
#  <td class="contact bottomline" rowspan="2">
#  <div class="inner">
#  <span class="title_agent" title="뉴시티부동산공인중개사사무소">뉴시티부동산공인중개사사무소</span><span class="tel">033-241-4919</span>
#  </div>
#  </td>
#  </tr>, <tr class="evennum _trow_1902476592">
#  <td class="desc bottomline" colspan="5">
#  <div class="inner">
#  <span class="txt" title="시세보다 완전저렴한 급매가격입니다. 정남향 햇볕쨍쨍">시세보다 완전저렴한 급매가격입니다. 정남향 햇볕쨍쨍</span>
#  <span class="txt_a">
#  <a class="tx NPI=a:cpsource" href="http://land.mk.co.kr/rd/rd.php?UID=1902476592" target="_blank">매경부동산</a>
#  </span>
#  </div>
#  </td>
#  </tr>, <tr class="_trow_1902473070">
#  <td class="sale_type" rowspan="2">
#  <div class="inner pl4" tabindex="0">매매</div>
#  </td>
#  <td class="sale_type2" rowspan="2" tabindex="0"><div class="inner" style="padding:0;">아파트</div></td>
#  <td class="" rowspan="2">
#  <div class="inner inner_mark">
#  <span class="mark4" title="확인한지 1개월 이내인 매물"><img alt="확인한지 1개월 이내인 매물" height="15" src="https://ssl.pstatic.net/static.land/static/service/20181108-2/article/blank.gif" style="background:url(https://ssl.pstatic.net/static.land/static/service/20181108-2/article/articlelist.gif) -100px -130px no-repeat;" width="48"/>19.01.30.</span>
#  </div>
#  </td>
#  <td class="align_l name" colspan="2">
#  <div class="inner">
#  <a class="NPI=a:list,r:30,i:1902473070 sale_title" href="#" onclick="nhn.article.common.moveArticleDetail('1902473070','A01','A01','A1', 'SERVE','false');return false;" title="진흥">진흥</a>
#  <span class="btn_naverlink">
#  <a class="NPI=a:listnew,r:30,i:1902473070" href="/article/articleDetailInfo.nhn?atclNo=1902473070&amp;atclRletTypeCd=A01&amp;rletTypeCd=A01&amp;tradeTypeCd=A1" target="_blank">네이버부동산에서 보기</a>
#  </span>
#  </div>
#  </td>
#  <td class="num" onmouseout="$Element($$.getSingle('div.inner',this)).css('zIndex', '0'); $Element($$.getSingle('div.rate_layer',this)).hide();" onmouseover="$Element($$.getSingle('div.inner',this)).css('zIndex', '10');$Element($$.getSingle('div.rate_layer',this)).show();">
#  <div class="inner" tabindex="0">
#  				76/59
#  				<div class="rate_layer" style="display:none;">
#  <div class="layer">
#  <p class="calc_area">
#  							공급면적 76.87㎡
#  							<br/>
#
#  							전용면적 59.15㎡
#  							<br/>
#  </p>
#  </div>
#  </div>
#  </div>
#  </td>
#  <td class="num2"><div class="inner" tabindex="0"><span>6/15</span></div></td>
#  <td class="num align_r">
#  <div class="inner">
#  <strong title="14,000">14,000</strong>
#  </div>
#  </td>
#  <td class="contact" rowspan="2">
#  <div class="inner">
#  <a href="javascript:nhn.article.common.moveRealtorPage('onetop17', null, true)">
#  <span class="title_agent" title="원탑공인중개사사무소">
#  							원탑공인중개사사무소
#  						</span>
#  <span class="tel">033-264-2244</span>
#  </a>
#  </div>
#  </td>
#  </tr>, <tr class="_trow_1902473070">
#  <td class="desc" colspan="5">
#  <div class="inner">
#  <span class="txt" title="기본형 내부상태깨끗">기본형 내부상태깨끗</span>
#  <span class="txt_a">
#  <a class="tx NPI=a:cpsource" href="http://www.serve.co.kr/naver/rd.asp?UID=1902473070" target="_blank">부동산써브</a>
#  </span>
#  </div>
#  </td>
#  </tr>]

# %%
import re

# 공백 문자 제거
pattern = re.compile(r'\s+')

# %% [markdown]
# 위에는 처음보는 함수죠? re 패키지를 사용하면 정규식을 활용해 문자열을 다룰수 있어요. 하나만 더 새로운걸 배워볼까요?
#
# 반복문을 활용하면서 값과 인덱스를 동시에 쓰고싶으신적이 많죠? 방법을 알려드릴께요!

# %%
리스트 = ['첫번째값', '두번째값', '세번째값', '네번째값', '다섯번째값']
for 인덱스, 값 in enumerate(리스트):
    print(인덱스, ': ',값)
# Out:
# 0 :  첫번째값
# 1 :  두번째값
# 2 :  세번째값
# 3 :  네번째값
# 4 :  다섯번째값

# %% [markdown]
# `enumerate`를 활용하면 리스트에 있는 값과 인덱스를 튜플(`tuple`)형태로 반환해요
#
# 진짜 마직막 하나만 더 해봐요!
#
# `zip`함수는 동일한 개수로 이루어진 자료형을 묶어 주는 역할을 하는 함수에요 직접 볼까요?

# %%
리스트_2 = ['사과', '딸기', '포도', '배', '사과']
합리스트 = list(zip(리스트, 리스트_2))
합리스트
# Out:
# [('첫번째값', '사과'),
#  ('두번째값', '딸기'),
#  ('세번째값', '포도'),
#  ('네번째값', '배'),
#  ('다섯번째값', '사과')]

# %%
# 위에껄 다 합치면 이런식을 사용할수도 있겠죠?
for 인덱스, (값순서, 값) in enumerate(zip(리스트, 리스트_2)):
    print(인덱스, 값순서, 값)
# Out:
# 0 첫번째값 사과
# 1 두번째값 딸기
# 2 세번째값 포도
# 3 네번째값 배
# 4 다섯번째값 사과

# %% [markdown]
# <img src="../image/4-7.jpg" alt="Drawing" style="width: 200px;"/>

# %% [markdown]
# 큼.... 너무 뜬금없이 너무 길어졌군요....
#
# 자 계속 해봅시다!

# %%
rows = []
for i, tr in enumerate(tbody):
    if i%2 != 0: # 2의 배수면 넘어가라는 코드입니다(2로 나눈 나머지가 0)
        continue
    row = []
    for i, td in enumerate(tr.select('td')):
        if i == 3:
            if td.select('img'): 
                continue
        row.append(re.sub(pattern,'', td.text))
    rows.append(row)

# %%
from pandas import DataFrame

df = DataFrame.from_records(rows, columns=['거래', '종류', '확인일자', '매물명', '면적(㎡)', '층', '매물가(만원)', '연락처'])
df.tail(5)
# Out:
#     거래   종류       확인일자                매물명                        면적(㎡)      층  \
# 25  매매  아파트  19.01.24.  집주인퇴계우성네이버부동산에서보기  110/84공급면적110.61㎡전용면적84.93㎡   3/18
# 26  월세  아파트  19.01.23.  집주인현대2차네이버부동산에서보기   78A/59공급면적78.18㎡전용면적59.76㎡  14/15
# 27  매매  아파트  19.01.22.   집주인그랜드네이버부동산에서보기  109/84공급면적109.55㎡전용면적84.95㎡   6/15
# 28  매매  아파트  19.01.30.       동부네이버부동산에서보기  103/84공급면적103.18㎡전용면적84.96㎡  11/15
# 29  매매  아파트  19.01.30.       진흥네이버부동산에서보기    76/59공급면적76.87㎡전용면적59.15㎡   6/15
#
#      매물가(만원)                          연락처
# 25    20,500    청담부동산공인중개사사무소033-244-7007
# 26  6,000/25  사랑채부동산공인중개사사무소010-8812-9578
# 27    20,300   그랜드부동산공인중개사사무소033-264-4289
# 28    14,900   뉴시티부동산공인중개사사무소033-241-4919
# 29    14,000       원탑공인중개사사무소033-264-2244

# %%
# 매물명에서 '네이버부동산에서보기' 제거
df['매물명'] = df['매물명'].apply(lambda x : x.replace('네이버부동산에서보기', ''))
df.tail(5)
# Out:
#     거래   종류       확인일자      매물명                        면적(㎡)      층   매물가(만원)  \
# 25  매매  아파트  19.01.24.  집주인퇴계우성  110/84공급면적110.61㎡전용면적84.93㎡   3/18    20,500
# 26  월세  아파트  19.01.23.  집주인현대2차   78A/59공급면적78.18㎡전용면적59.76㎡  14/15  6,000/25
# 27  매매  아파트  19.01.22.   집주인그랜드  109/84공급면적109.55㎡전용면적84.95㎡   6/15    20,300
# 28  매매  아파트  19.01.30.       동부  103/84공급면적103.18㎡전용면적84.96㎡  11/15    14,900
# 29  매매  아파트  19.01.30.       진흥    76/59공급면적76.87㎡전용면적59.15㎡   6/15    14,000
#
#                             연락처
# 25    청담부동산공인중개사사무소033-244-7007
# 26  사랑채부동산공인중개사사무소010-8812-9578
# 27   그랜드부동산공인중개사사무소033-264-4289
# 28   뉴시티부동산공인중개사사무소033-241-4919
# 29       원탑공인중개사사무소033-264-2244

# %%
df[df['매물가(만원)'] == '3,000/9018.10.01.자호가일뿐실거래가로확인된금액이아닙니다.']
# Out:
# Empty DataFrame
# Columns: [거래, 종류, 확인일자, 매물명, 면적(㎡), 층, 매물가(만원), 연락처]
# Index: []

# %%
droplist = []
for i, row in enumerate(df.iterrows()):
    if '실거래가로확인된금액이아닙니다' in row[1]['매물가(만원)']:
        droplist.append(i)

df = df.drop(droplist, axis=0)
df.head(5)
# Out:
#    거래   종류       확인일자        매물명                         면적(㎡)      층 매물가(만원)  \
# 0  매매  아파트  19.01.31.  집주인춘천두산위브   107C/84공급면적107.5㎡전용면적84.96㎡   7/15  23,500
# 1  매매  아파트  19.01.31.  집주인춘천두산위브  108A/84공급면적108.73㎡전용면적84.98㎡   7/15  24,000
# 2  전세  아파트  19.01.29.    집주인그린타운   119/99공급면적119.82㎡전용면적99.99㎡   8/15  18,000
# 3  전세  아파트  19.01.29.    집주인현대1차   104/84공급면적104.96㎡전용면적84.99㎡   4/15  16,000
# 4  전세  아파트  19.01.29.  집주인춘천두산위브  108A/84공급면적108.73㎡전용면적84.98㎡  15/15  21,000
#
#                            연락처
# 0       두산공인중개사사무소033-241-8959
# 1       두산공인중개사사무소033-241-8959
# 2   그랜드부동산공인중개사사무소033-264-4289
# 3  사랑채부동산공인중개사사무소010-8812-9578
# 4       두산공인중개사사무소033-241-8959

# %%
#'/'로 split후에 천단위 쉼표제거 후 정수형변환
df['매물가(만원)'] = df['매물가(만원)'].apply(lambda x: int(x.split('/')[0].replace(',','')))
df.head(5)
# Out:
#    거래   종류       확인일자        매물명                         면적(㎡)      층  \
# 0  매매  아파트  19.01.31.  집주인춘천두산위브   107C/84공급면적107.5㎡전용면적84.96㎡   7/15
# 1  매매  아파트  19.01.31.  집주인춘천두산위브  108A/84공급면적108.73㎡전용면적84.98㎡   7/15
# 2  전세  아파트  19.01.29.    집주인그린타운   119/99공급면적119.82㎡전용면적99.99㎡   8/15
# 3  전세  아파트  19.01.29.    집주인현대1차   104/84공급면적104.96㎡전용면적84.99㎡   4/15
# 4  전세  아파트  19.01.29.  집주인춘천두산위브  108A/84공급면적108.73㎡전용면적84.98㎡  15/15
#
#    매물가(만원)                          연락처
# 0    23500       두산공인중개사사무소033-241-8959
# 1    24000       두산공인중개사사무소033-241-8959
# 2    18000   그랜드부동산공인중개사사무소033-264-4289
# 3    16000  사랑채부동산공인중개사사무소010-8812-9578
# 4    21000       두산공인중개사사무소033-241-8959

# %% [markdown]
# ---

# %% [markdown]
# 크롤링을 잘 하려면 html의 구조에 대해서 잘 알고있어야 해요. 해당 내용은 다루지 않으나, 크롤링을 제대로 하려면 해당내용에 관한 학습이 필요합니다.
